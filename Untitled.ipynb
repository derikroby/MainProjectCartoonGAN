# %% [markdown]
# # Email Classification using Artificial Neural Networks(Tensor Flow)
# ### This is an implementation of A TensorFlow Tutorial: Email Classification by Josh Meyer's
# http://jrmeyer.github.io/machinelearning/2016/02/01/TensorFlow-Tutorial.html

# %% [markdown]
# Instead of telling the program which words we think are important to classify an email as spam or ham, let’s let the program learn which words are actually important.
#
# ### Dataset
#
# Each email has already been labeled as Spam or Ham. Since we are making use of these labels in the training phase, this is a supervised learning task.  We are using pre-processed emails.
#
# ### Working
#
# During the training phase, we present these emails and their labels to the program. For each email, the program says whether it thought the email was Spam or Ham. After the program makes a prediction, we tell the program what the label of the email actually was. The program then changes its configuration so as to make a better prediction the next time around. This process is done iteratively until either the program can’t do any better or we get impatient and just tell the program to stop.

# %% [markdown]
# ### Code

# %% [markdown]
# Import dependencies

# %%
################
### PREAMBLE ###
################

from __future__ import division
import tensorflow as tf
import numpy as np
import tarfile
import os
import matplotlib.pyplot as plt
import time

# %% [markdown]
# The import_data() function first checks if the data directory “data/” exists in your current working directory or not. If it doesn’t exist, the code tries to unzip the tarred data from the file “data.tar.gz”, which is expected to be in your current working directory.

# %%
###################
### IMPORT DATA ###
###################

def csv_to_numpy_array(filePath, delimiter):
    return np.genfromtxt(filePath, delimiter=delimiter, dtype=None)

def import_data():
    if "data" not in os.listdir(os.getcwd()):
        # Untar directory of data if we haven't already
        tarObject = tarfile.open("data.tar.gz")
        tarObject.extractall()
        tarObject.close()
        print("Extracted tar to current directory")
    else:
        # we've already extracted the files
        pass

    print("loading training data")
    trainX = csv_to_numpy_array("data/trainX.csv", delimiter="\t")
    trainY = csv_to_numpy_array("data/trainY.csv", delimiter="\t")
    print("loading test data")
    testX = csv_to_numpy_array("data/testX.csv", delimiter="\t")
    testY = csv_to_numpy_array("data/testY.csv", delimiter="\t")
    return trainX,trainY,testX,testY

trainX,trainY,testX,testY = import_data()
# Out:
# loading training data
# loading test data

# %% [markdown]
# Here we set our global parameters

# %%
########################
### GLOBAL PARAMETERS ###
#########################

# DATA SET PARAMETERS
# Get our dimensions for our different variables and placeholders:
# numFeatures = the number of words extracted from each email
numFeatures = trainX.shape[1]
# numLabels = number of classes we are predicting (here just 2: Ham or Spam)
numLabels = trainY.shape[1]

# TRAINING SESSION PARAMETERS
# number of times we iterate through training data
# tensorboard shows that accuracy plateaus at ~25k epochs
numEpochs = 25000
# a smarter learning rate for gradientOptimizer
learningRate = tf.train.exponential_decay(learning_rate=0.0008,
                                          global_step= 1,
                                          decay_steps=trainX.shape[0],
                                          decay_rate= 0.95,
                                          staircase=True)

# %% [markdown]
# ### TensorFlow Placeholders
#
# These placeholders will hold our email data (both the features and label matrices), and help pass them along to different parts of the algorithm. You can think of placeholders as empty shells (i.e. empty tensors) into which we insert our data. As such, when we define the placeholders we need to give them shapes which correspond to the shape of our data.
#
# The way TensorFlow allows us to insert data into these placeholders is by “feeding” the placeholders the data via a “feed_dict”.
#
# This is a nice feature of TensorFlow because we can create an algorithm which accepts data and knows something about the shape of the data while still being agnostic about the amount of data going in. This means that when we insert “batches” of data in training, we can easily adjust how many examples we train on in a single step without changing the entire algorithm.
#
# In TensorFlow terms, we build the computation graph and then insert data as we wish. This keeps a clean division between the computations of our algoritm and the data we’re doing the computations on.

# %%
####################
### PLACEHOLDERS ###
####################

# X = X-matrix / feature-matrix / data-matrix... It's a tensor to hold our email
# data. 'None' here means that we can hold any number of emails
X = tf.placeholder(tf.float32, [None, numFeatures])
# yGold = Y-matrix / label-matrix / labels... This will be our correct answers
# matrix. Every row has either [1,0] for SPAM or [0,1] for HAM. 'None' here 
# means that we can hold any number of emails
yGold = tf.placeholder(tf.float32, [None, numLabels])

# %% [markdown]
# ### Tensorflow variables
#
# Next, we define some TensorFlow variables as our parameters. These variables will hold the weights and biases of our logistic regression and they will be continually updated during training. Unlike the immutable TensorFlow constants, TensorFlow variables can change their values within a session.
#
# This is essential for any optimization algorithm to work (we will use gradient descent). These variables are the objects which define the structure of our regression model, and we can save them after they’ve been trained so we can reuse them later.
#
# Variables, like all data in TensorFlow, are represented as tensors. However, unlike our placeholders above which are essentially empty shells waiting to be fed data, TensorFlow variables need to be initialized with values.
#
# That’s why in the code below which initializes the variables, we use tf.random_normal to sample from a normal distribution to fill a tensor of shape “shape” with random values. Both our weights and bias term are initialized randomly and updated during training.

# %%
#################
### VARIABLES ###
#################

# Values are randomly sampled from a Gaussian with a standard deviation of:
#     sqrt(6 / (numInputNodes + numOutputNodes + 1))

weights = tf.Variable(tf.random_normal([numFeatures,numLabels],
                                       mean=0,
                                       stddev=(np.sqrt(6/numFeatures+
                                                         numLabels+1)),
                                       name="weights"))

bias = tf.Variable(tf.random_normal([1,numLabels],
                                    mean=0,
                                    stddev=(np.sqrt(6/numFeatures+numLabels+1)),
                                    name="bias"))

# %% [markdown]
# ### Tensorflow ops
#
# Up until this point, we have defined the different tensors which will hold important information. Specifically, we have defined
# (1) the tensors which hold the email data (feature and label matrices)
# (2) the tensors which hold our regression weights and biases.
#
# Now we will switch gears to define the computations which will act upon those tensors. In TensorFlow terms, these computations are called operations (or “ops” for short). These ops will be the nodes in our computational graph. Ops take tensors as input and give back tensors as output.
#
# In the illustration below, the green nodes represent our TensorFlow placeholders (holding features and labels), the blue nodes represent our TensorFlow variables (holding weights and biases), and the pink nodes represent our TensorFlow Ops (operations on our tensors).

# %%
######################
### PREDICTION OPS ###
######################

# INITIALIZE our weights and biases
init_OP = tf.initialize_all_variables()

# PREDICTION ALGORITHM i.e. FEEDFORWARD ALGORITHM
apply_weights_OP = tf.matmul(X, weights, name="apply_weights")
add_bias_OP = tf.add(apply_weights_OP, bias, name="add_bias") 
activation_OP = tf.nn.sigmoid(add_bias_OP, name="activation")
# Out:
# WARNING:tensorflow:From /home/derik/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_should_use.py:118: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.

# %% [markdown]
# Loss function, 12∑Ni=1(y^i−yi)2.

# %%
#####################
### EVALUATION OP ###
#####################

# COST FUNCTION i.e. MEAN SQUARED ERROR
cost_OP = tf.nn.l2_loss(activation_OP-yGold, name="squared_error_cost")

# %% [markdown]
# Next, we define the function to optimize our cost function. We are using gradient descent, which TensorFlow has a built in op for.

# %%
#######################
### OPTIMIZATION OP ###
#######################

# OPTIMIZATION ALGORITHM i.e. GRADIENT DESCENT
training_OP = tf.train.GradientDescentOptimizer(learningRate).minimize(cost_OP)

# %% [markdown]
# Visualization in matplotlib

# %%
###########################
### GRAPH LIVE UPDATING ###
###########################

epoch_values=[]
accuracy_values=[]
cost_values=[]
# Turn on interactive plotting
plt.ion()
# Create the main, super plot
fig = plt.figure()
# Create two subplots on their own axes and give titles
ax1 = plt.subplot("211")
ax1.set_title("TRAINING ACCURACY", fontsize=18)
ax2 = plt.subplot("212")
ax2.set_title("TRAINING COST", fontsize=18)
plt.tight_layout()
#####################
### RUN THE GRAPH ###
#####################

# Create a tensorflow session
sess = tf.Session()

# Initialize all tensorflow variables
sess.run(init_OP)

## Ops for vizualization
# argmax(activation_OP, 1) gives the label our model thought was most likely
# argmax(yGold, 1) is the correct label
correct_predictions_OP = tf.equal(tf.argmax(activation_OP,1),tf.argmax(yGold,1))
# False is 0 and True is 1, what was our average?
accuracy_OP = tf.reduce_mean(tf.cast(correct_predictions_OP, "float"))
# Summary op for regression output
activation_summary_OP = tf.summary.histogram("output", activation_OP)
# Summary op for accuracy
accuracy_summary_OP = tf.summary.scalar("accuracy", accuracy_OP)
# Summary op for cost
cost_summary_OP = tf.summary.scalar("cost", cost_OP)
# Summary ops to check how variables (W, b) are updating after each iteration
weightSummary = tf.summary.histogram("weights", weights.eval(session=sess))
biasSummary = tf.summary.histogram("biases", bias.eval(session=sess))
# Merge all summaries
all_summary_OPS = tf.summary.merge_all()
# Summary writer
writer = tf.summary.FileWriter("summary_logs", sess.graph)

# Initialize reporting variables
cost = 0
diff = 1

# Training epochs
for i in range(numEpochs):
    if i > 1 and diff < .0001:
        print("change in cost %g; convergence."%diff)
        break
    else:
        # Run training step
        step = sess.run(training_OP, feed_dict={X: trainX, yGold: trainY})
        # Report occasional stats
        if i % 10 == 0:
            # Add epoch to epoch_values
            epoch_values.append(i)
            # Generate accuracy stats on test data
            summary_results, train_accuracy, newCost = sess.run(
                [all_summary_OPS, accuracy_OP, cost_OP], 
                feed_dict={X: trainX, yGold: trainY}
            )
            # Add accuracy to live graphing variable
            accuracy_values.append(train_accuracy)
            # Add cost to live graphing variable
            cost_values.append(newCost)
            # Write summary stats to writer
            writer.add_summary(summary_results, i)
            # Re-assign values for variables
            diff = abs(newCost - cost)
            cost = newCost

            #generate print statements
            print("step %d, training accuracy %g"%(i, train_accuracy))
            print("step %d, cost %g"%(i, newCost))
            print("step %d, change in cost %g"%(i, diff))

            # Plot progress to our two subplots
            accuracyLine, = ax1.plot(epoch_values, accuracy_values)
            costLine, = ax2.plot(epoch_values, cost_values)
            fig.canvas.draw()
            time.sleep(1)


# How well do we perform on held-out test data?
print("final accuracy on test set: %s" %str(sess.run(accuracy_OP, 
                                                     feed_dict={X: testX, 
                                                                yGold: testY})))
# Out:
# step 0, training accuracy 0.466946
# step 0, cost 378.965
# step 0, change in cost 378.965
# step 10, training accuracy 0.466946
# step 10, cost 343.538
# step 10, change in cost 35.4268
# step 20, training accuracy 0.466946
# step 20, cost 307.045
# step 20, change in cost 36.493
# step 30, training accuracy 0.466946
# step 30, cost 276.09
# step 30, change in cost 30.9557
# step 40, training accuracy 0.465897
# step 40, cost 254.868
# step 40, change in cost 21.2218
# step 50, training accuracy 0.449108
# step 50, cost 243.515
# step 50, change in cost 11.353
# step 60, training accuracy 0.490031
# step 60, cost 238.492
# step 60, change in cost 5.02318
# step 70, training accuracy 0.573977
# step 70, cost 236.448
# step 70, change in cost 2.04338
# step 80, training accuracy 0.592865
# step 80, cost 235.617
# step 80, change in cost 0.831314
# step 90, training accuracy 0.586569
# step 90, cost 235.253
# step 90, change in cost 0.363693
# step 100, training accuracy 0.577125
# step 100, cost 235.068
# step 100, change in cost 0.185669
# step 110, training accuracy 0.570829
# step 110, cost 234.949
# step 110, change in cost 0.118134
# step 120, training accuracy 0.567681
# step 120, cost 234.857
# step 120, change in cost 0.0924225
# step 130, training accuracy 0.567681
# step 130, cost 234.774
# step 130, change in cost 0.0825653
# step 140, training accuracy 0.566632
# step 140, cost 234.696
# step 140, change in cost 0.0788116
# step 150, training accuracy 0.566632
# step 150, cost 234.618
# step 150, change in cost 0.0773468
# step 160, training accuracy 0.56873
# step 160, cost 234.542
# step 160, change in cost 0.0766907
# step 170, training accuracy 0.56873
# step 170, cost 234.465
# step 170, change in cost 0.0765381
# step 180, training accuracy 0.56873
# step 180, cost 234.389
# step 180, change in cost 0.0763245
# step 190, training accuracy 0.56873
# step 190, cost 234.312
# step 190, change in cost 0.0763245
# step 200, training accuracy 0.56873
# step 200, cost 234.236
# step 200, change in cost 0.0762634
# step 210, training accuracy 0.56873
# step 210, cost 234.16
# step 210, change in cost 0.0761261
# step 220, training accuracy 0.56873
# step 220, cost 234.084
# step 220, change in cost 0.0761871
# step 230, training accuracy 0.56873
# step 230, cost 234.008
# step 230, change in cost 0.0760956
# step 240, training accuracy 0.56873
# step 240, cost 233.932
# step 240, change in cost 0.0760345
# step 250, training accuracy 0.56873
# step 250, cost 233.856
# step 250, change in cost 0.0760498
# step 260, training accuracy 0.56873
# step 260, cost 233.78
# step 260, change in cost 0.0759277
# step 270, training accuracy 0.56873
# step 270, cost 233.704
# step 270, change in cost 0.075943
# step 280, training accuracy 0.56978
# step 280, cost 233.628
# step 280, change in cost 0.0758972
# step 290, training accuracy 0.56978
# step 290, cost 233.552
# step 290, change in cost 0.0758362
# step 300, training accuracy 0.56978
# step 300, cost 233.476
# step 300, change in cost 0.0758209
# step 310, training accuracy 0.570829
# step 310, cost 233.4
# step 310, change in cost 0.0757599
# step 320, training accuracy 0.570829
# step 320, cost 233.325
# step 320, change in cost 0.0757294
# step 330, training accuracy 0.570829
# step 330, cost 233.249
# step 330, change in cost 0.0756836
# step 340, training accuracy 0.570829
# step 340, cost 233.173
# step 340, change in cost 0.0755768
# step 350, training accuracy 0.570829
# step 350, cost 233.098
# step 350, change in cost 0.0756073
# step 360, training accuracy 0.571878
# step 360, cost 233.022
# step 360, change in cost 0.0755463
# step 370, training accuracy 0.572928
# step 370, cost 232.947
# step 370, change in cost 0.0755005
# step 380, training accuracy 0.572928
# step 380, cost 232.871
# step 380, change in cost 0.0754852
# step 390, training accuracy 0.573977
# step 390, cost 232.796
# step 390, change in cost 0.0753937
# step 400, training accuracy 0.573977
# step 400, cost 232.721
# step 400, change in cost 0.0753784
# step 410, training accuracy 0.573977
# step 410, cost 232.645
# step 410, change in cost 0.0753021
# step 420, training accuracy 0.575026
# step 420, cost 232.57
# step 420, change in cost 0.0753326
# step 430, training accuracy 0.575026
# step 430, cost 232.495
# step 430, change in cost 0.0752258
# step 440, training accuracy 0.575026
# step 440, cost 232.419
# step 440, change in cost 0.0751801
# step 450, training accuracy 0.575026
# step 450, cost 232.344
# step 450, change in cost 0.0751495
# step 460, training accuracy 0.576076
# step 460, cost 232.269
# step 460, change in cost 0.0751648
# step 470, training accuracy 0.576076
# step 470, cost 232.194
# step 470, change in cost 0.0750275
# step 480, training accuracy 0.576076
# step 480, cost 232.119
# step 480, change in cost 0.0751038
# step 490, training accuracy 0.576076
# step 490, cost 232.044
# step 490, change in cost 0.0749664
# step 500, training accuracy 0.576076
# step 500, cost 231.969
# step 500, change in cost 0.0749664
# step 510, training accuracy 0.576076
# step 510, cost 231.894
# step 510, change in cost 0.0748901
# step 520, training accuracy 0.576076
# step 520, cost 231.819
# step 520, change in cost 0.0748596
# step 530, training accuracy 0.576076
# step 530, cost 231.745
# step 530, change in cost 0.0747986
# step 540, training accuracy 0.577125
# step 540, cost 231.67
# step 540, change in cost 0.0747833
# step 550, training accuracy 0.577125
# step 550, cost 231.595
# step 550, change in cost 0.0747375
# step 560, training accuracy 0.577125
# step 560, cost 231.52
# step 560, change in cost 0.0746918
# step 570, training accuracy 0.577125
# step 570, cost 231.446
# step 570, change in cost 0.074646
# step 580, training accuracy 0.577125
# step 580, cost 231.371
# step 580, change in cost 0.0746307
# step 590, training accuracy 0.577125
# step 590, cost 231.297
# step 590, change in cost 0.0745392
# step 600, training accuracy 0.577125
# step 600, cost 231.222
# step 600, change in cost 0.0744934
# step 610, training accuracy 0.577125
# step 610, cost 231.147
# step 610, change in cost 0.0745544
# step 620, training accuracy 0.577125
# step 620, cost 231.073
# step 620, change in cost 0.0743866
# step 630, training accuracy 0.577125
# step 630, cost 230.999
# step 630, change in cost 0.0743866
# step 640, training accuracy 0.577125
# step 640, cost 230.924
# step 640, change in cost 0.0743408
# step 650, training accuracy 0.577125
# step 650, cost 230.85
# step 650, change in cost 0.0743408
# step 660, training accuracy 0.578174
# step 660, cost 230.776
# step 660, change in cost 0.074234
# step 670, training accuracy 0.578174
# step 670, cost 230.702
# step 670, change in cost 0.0742493
# step 680, training accuracy 0.578174
# step 680, cost 230.627
# step 680, change in cost 0.0741882
# step 690, training accuracy 0.579224
# step 690, cost 230.553
# step 690, change in cost 0.0741272
# step 700, training accuracy 0.579224
# step 700, cost 230.479
# step 700, change in cost 0.0741119
# step 710, training accuracy 0.579224
# step 710, cost 230.405
# step 710, change in cost 0.0740356
# step 720, training accuracy 0.580273
# step 720, cost 230.331
# step 720, change in cost 0.0740204
# step 730, training accuracy 0.581322
# step 730, cost 230.257
# step 730, change in cost 0.0739746
# step 740, training accuracy 0.581322
# step 740, cost 230.183
# step 740, change in cost 0.0738983
# step 750, training accuracy 0.581322
# step 750, cost 230.109
# step 750, change in cost 0.0738831
# step 760, training accuracy 0.581322
# step 760, cost 230.035
# step 760, change in cost 0.0738068
# step 770, training accuracy 0.581322
# step 770, cost 229.962
# step 770, change in cost 0.0738373
# step 780, training accuracy 0.582371
# step 780, cost 229.888
# step 780, change in cost 0.073761
# step 790, training accuracy 0.582371
# step 790, cost 229.814
# step 790, change in cost 0.0737305
# step 800, training accuracy 0.585519
# step 800, cost 229.74
# step 800, change in cost 0.0736847
# step 810, training accuracy 0.585519
# step 810, cost 229.667
# step 810, change in cost 0.0736237
# step 820, training accuracy 0.585519
# step 820, cost 229.593
# step 820, change in cost 0.0735779
# step 830, training accuracy 0.585519
# step 830, cost 229.52
# step 830, change in cost 0.0735626
# step 840, training accuracy 0.585519
# step 840, cost 229.446
# step 840, change in cost 0.0734711
# step 850, training accuracy 0.586569
# step 850, cost 229.373
# step 850, change in cost 0.0734863
# step 860, training accuracy 0.586569
# step 860, cost 229.299
# step 860, change in cost 0.0734253
# step 870, training accuracy 0.586569
# step 870, cost 229.226
# step 870, change in cost 0.0733643
# step 880, training accuracy 0.586569
# step 880, cost 229.153
# step 880, change in cost 0.0733337
# step 890, training accuracy 0.586569
# step 890, cost 229.079
# step 890, change in cost 0.073288
# step 900, training accuracy 0.586569
# step 900, cost 229.006
# step 900, change in cost 0.0732269
# step 910, training accuracy 0.586569
# step 910, cost 228.933
# step 910, change in cost 0.0732727
# step 920, training accuracy 0.587618
# step 920, cost 228.86
# step 920, change in cost 0.0731201
# step 930, training accuracy 0.588667
# step 930, cost 228.787
# step 930, change in cost 0.0731506
# step 940, training accuracy 0.588667
# step 940, cost 228.713
# step 940, change in cost 0.0730896
# step 950, training accuracy 0.589717
# step 950, cost 228.64
# step 950, change in cost 0.0730133
# step 960, training accuracy 0.590766
# step 960, cost 228.567
# step 960, change in cost 0.0730286
# step 970, training accuracy 0.590766
# step 970, cost 228.494
# step 970, change in cost 0.0729523
# step 980, training accuracy 0.591815
# step 980, cost 228.422
# step 980, change in cost 0.0728912
# step 990, training accuracy 0.591815
# step 990, cost 228.349
# step 990, change in cost 0.0728912
# step 1000, training accuracy 0.592865
# step 1000, cost 228.276
# step 1000, change in cost 0.0728302
# step 1010, training accuracy 0.593914
# step 1010, cost 228.203
# step 1010, change in cost 0.0727844
# step 1020, training accuracy 0.593914
# step 1020, cost 228.13
# step 1020, change in cost 0.0727081
# step 1030, training accuracy 0.593914
# step 1030, cost 228.058
# step 1030, change in cost 0.0727081
# step 1040, training accuracy 0.594963
# step 1040, cost 227.985
# step 1040, change in cost 0.0726624
# step 1050, training accuracy 0.596013
# step 1050, cost 227.912
# step 1050, change in cost 0.0726471
# step 1060, training accuracy 0.596013
# step 1060, cost 227.84
# step 1060, change in cost 0.0725555
# step 1070, training accuracy 0.596013
# step 1070, cost 227.767
# step 1070, change in cost 0.0725555
# step 1080, training accuracy 0.596013
# step 1080, cost 227.695
# step 1080, change in cost 0.0724945
# step 1090, training accuracy 0.596013
# step 1090, cost 227.622
# step 1090, change in cost 0.0724792
# step 1100, training accuracy 0.596013
# step 1100, cost 227.55
# step 1100, change in cost 0.0723724
# step 1110, training accuracy 0.597062
# step 1110, cost 227.477
# step 1110, change in cost 0.0724182
# step 1120, training accuracy 0.598111
# step 1120, cost 227.405
# step 1120, change in cost 0.0722809
# step 1130, training accuracy 0.598111
# step 1130, cost 227.333
# step 1130, change in cost 0.0722809
# step 1140, training accuracy 0.598111
# step 1140, cost 227.261
# step 1140, change in cost 0.0722198
# step 1150, training accuracy 0.598111
# step 1150, cost 227.189
# step 1150, change in cost 0.0722046
# step 1160, training accuracy 0.598111
# step 1160, cost 227.116
# step 1160, change in cost 0.0722046
# step 1170, training accuracy 0.599161
# step 1170, cost 227.044
# step 1170, change in cost 0.0721436
# step 1180, training accuracy 0.599161
# step 1180, cost 226.972
# step 1180, change in cost 0.0720673
# step 1190, training accuracy 0.599161
# step 1190, cost 226.9
# step 1190, change in cost 0.0720215
# step 1200, training accuracy 0.599161
# step 1200, cost 226.828
# step 1200, change in cost 0.0719757
# step 1210, training accuracy 0.599161
# step 1210, cost 226.756
# step 1210, change in cost 0.071991
# step 1220, training accuracy 0.60021
# step 1220, cost 226.684
# step 1220, change in cost 0.0718842
# step 1230, training accuracy 0.60021
# step 1230, cost 226.612
# step 1230, change in cost 0.0718994
# step 1240, training accuracy 0.60021
# step 1240, cost 226.54
# step 1240, change in cost 0.0718231
# step 1250, training accuracy 0.601259
# step 1250, cost 226.469
# step 1250, change in cost 0.0717316
# step 1260, training accuracy 0.601259
# step 1260, cost 226.397
# step 1260, change in cost 0.0717926
# step 1270, training accuracy 0.601259
# step 1270, cost 226.325
# step 1270, change in cost 0.0716705
# step 1280, training accuracy 0.601259
# step 1280, cost 226.254
# step 1280, change in cost 0.0716248
# step 1290, training accuracy 0.604407
# step 1290, cost 226.182
# step 1290, change in cost 0.0716705
# step 1300, training accuracy 0.604407
# step 1300, cost 226.11
# step 1300, change in cost 0.0715942
# step 1310, training accuracy 0.605456
# step 1310, cost 226.039
# step 1310, change in cost 0.0715027
# step 1320, training accuracy 0.605456
# step 1320, cost 225.967
# step 1320, change in cost 0.0715179
# step 1330, training accuracy 0.605456
# step 1330, cost 225.896
# step 1330, change in cost 0.0714417
# step 1340, training accuracy 0.605456
# step 1340, cost 225.825
# step 1340, change in cost 0.0713959
# step 1350, training accuracy 0.606506
# step 1350, cost 225.753
# step 1350, change in cost 0.0713959
# step 1360, training accuracy 0.608604
# step 1360, cost 225.682
# step 1360, change in cost 0.0713043
# step 1370, training accuracy 0.608604
# step 1370, cost 225.611
# step 1370, change in cost 0.0712891
# step 1380, training accuracy 0.610703
# step 1380, cost 225.539
# step 1380, change in cost 0.0712128
# step 1390, training accuracy 0.611752
# step 1390, cost 225.468
# step 1390, change in cost 0.0712128
# step 1400, training accuracy 0.611752
# step 1400, cost 225.397
# step 1400, change in cost 0.0711517
# step 1410, training accuracy 0.613851
# step 1410, cost 225.326
# step 1410, change in cost 0.071167
# step 1420, training accuracy 0.61595
# step 1420, cost 225.255
# step 1420, change in cost 0.0710602
# step 1430, training accuracy 0.616999
# step 1430, cost 225.184
# step 1430, change in cost 0.0710449
# step 1440, training accuracy 0.618048
# step 1440, cost 225.113
# step 1440, change in cost 0.0710297
# step 1450, training accuracy 0.618048
# step 1450, cost 225.042
# step 1450, change in cost 0.0709534
# step 1460, training accuracy 0.618048
# step 1460, cost 224.971
# step 1460, change in cost 0.0708923
# step 1470, training accuracy 0.618048
# step 1470, cost 224.9
# step 1470, change in cost 0.0708771
# step 1480, training accuracy 0.619098
# step 1480, cost 224.829
# step 1480, change in cost 0.0708008
# step 1490, training accuracy 0.619098
# step 1490, cost 224.758
# step 1490, change in cost 0.0708008
# step 1500, training accuracy 0.621196
# step 1500, cost 224.688
# step 1500, change in cost 0.0707703
# step 1510, training accuracy 0.621196
# step 1510, cost 224.617
# step 1510, change in cost 0.0707092
# step 1520, training accuracy 0.622246
# step 1520, cost 224.546
# step 1520, change in cost 0.0706787
# step 1530, training accuracy 0.622246
# step 1530, cost 224.476
# step 1530, change in cost 0.0705872
# step 1540, training accuracy 0.622246
# step 1540, cost 224.405
# step 1540, change in cost 0.0706024
# step 1550, training accuracy 0.622246
# step 1550, cost 224.334
# step 1550, change in cost 0.0705719
# step 1560, training accuracy 0.622246
# step 1560, cost 224.264
# step 1560, change in cost 0.0704956
# step 1570, training accuracy 0.623295
# step 1570, cost 224.194
# step 1570, change in cost 0.0704346
# step 1580, training accuracy 0.624344
# step 1580, cost 224.123
# step 1580, change in cost 0.0704193
# step 1590, training accuracy 0.624344
# step 1590, cost 224.053
# step 1590, change in cost 0.0703888
# step 1600, training accuracy 0.624344
# step 1600, cost 223.982
# step 1600, change in cost 0.0703278
# step 1610, training accuracy 0.625394
# step 1610, cost 223.912
# step 1610, change in cost 0.0702515
# step 1620, training accuracy 0.625394
# step 1620, cost 223.842
# step 1620, change in cost 0.0703278
# step 1630, training accuracy 0.626443
# step 1630, cost 223.772
# step 1630, change in cost 0.0701599
# step 1640, training accuracy 0.627492
# step 1640, cost 223.701
# step 1640, change in cost 0.0701904
# step 1650, training accuracy 0.628541
# step 1650, cost 223.631
# step 1650, change in cost 0.0701447
# step 1660, training accuracy 0.628541
# step 1660, cost 223.561
# step 1660, change in cost 0.0700989
# step 1670, training accuracy 0.629591
# step 1670, cost 223.491
# step 1670, change in cost 0.0700531
# step 1680, training accuracy 0.63064
# step 1680, cost 223.421
# step 1680, change in cost 0.0700226
# step 1690, training accuracy 0.634837
# step 1690, cost 223.351
# step 1690, change in cost 0.0699615
# step 1700, training accuracy 0.634837
# step 1700, cost 223.281
# step 1700, change in cost 0.0699158
# step 1710, training accuracy 0.634837
# step 1710, cost 223.211
# step 1710, change in cost 0.0698853
# step 1720, training accuracy 0.635887
# step 1720, cost 223.142
# step 1720, change in cost 0.0698547
# step 1730, training accuracy 0.635887
# step 1730, cost 223.072
# step 1730, change in cost 0.0697784
# step 1740, training accuracy 0.636936
# step 1740, cost 223.002
# step 1740, change in cost 0.0697784
# step 1750, training accuracy 0.636936
# step 1750, cost 222.932
# step 1750, change in cost 0.0697479
# step 1760, training accuracy 0.640084
# step 1760, cost 222.863
# step 1760, change in cost 0.0696716
# step 1770, training accuracy 0.641133
# step 1770, cost 222.793
# step 1770, change in cost 0.0696106
# step 1780, training accuracy 0.641133
# step 1780, cost 222.723
# step 1780, change in cost 0.0696259
# step 1790, training accuracy 0.641133
# step 1790, cost 222.654
# step 1790, change in cost 0.0695343
# step 1800, training accuracy 0.641133
# step 1800, cost 222.584
# step 1800, change in cost 0.0695648
# step 1810, training accuracy 0.641133
# step 1810, cost 222.515
# step 1810, change in cost 0.069458
# step 1820, training accuracy 0.641133
# step 1820, cost 222.445
# step 1820, change in cost 0.0694122
# step 1830, training accuracy 0.641133
# step 1830, cost 222.376
# step 1830, change in cost 0.0694275
# step 1840, training accuracy 0.641133
# step 1840, cost 222.307
# step 1840, change in cost 0.0693359
# step 1850, training accuracy 0.643232
# step 1850, cost 222.237
# step 1850, change in cost 0.0693512
# step 1860, training accuracy 0.64638
# step 1860, cost 222.168
# step 1860, change in cost 0.0692596
# step 1870, training accuracy 0.648479
# step 1870, cost 222.099
# step 1870, change in cost 0.0692291
# step 1880, training accuracy 0.648479
# step 1880, cost 222.03
# step 1880, change in cost 0.0691681
# step 1890, training accuracy 0.650577
# step 1890, cost 221.96
# step 1890, change in cost 0.0691833
# step 1900, training accuracy 0.652676
# step 1900, cost 221.891
# step 1900, change in cost 0.0691223
# step 1910, training accuracy 0.653725
# step 1910, cost 221.822
# step 1910, change in cost 0.069046
# step 1920, training accuracy 0.654774
# step 1920, cost 221.753
# step 1920, change in cost 0.0690613
# step 1930, training accuracy 0.656873
# step 1930, cost 221.684
# step 1930, change in cost 0.0689697
# step 1940, training accuracy 0.656873
# step 1940, cost 221.615
# step 1940, change in cost 0.068985
# step 1950, training accuracy 0.657922
# step 1950, cost 221.546
# step 1950, change in cost 0.0688934
# step 1960, training accuracy 0.658972
# step 1960, cost 221.477
# step 1960, change in cost 0.0688782
# step 1970, training accuracy 0.660021
# step 1970, cost 221.409
# step 1970, change in cost 0.0688171
# step 1980, training accuracy 0.660021
# step 1980, cost 221.34
# step 1980, change in cost 0.0687866
# step 1990, training accuracy 0.66107
# step 1990, cost 221.271
# step 1990, change in cost 0.0687714
# step 2000, training accuracy 0.66107
# step 2000, cost 221.202
# step 2000, change in cost 0.0687256
# step 2010, training accuracy 0.66107
# step 2010, cost 221.134
# step 2010, change in cost 0.0686646
# step 2020, training accuracy 0.66107
# step 2020, cost 221.065
# step 2020, change in cost 0.0686035
# step 2030, training accuracy 0.66107
# step 2030, cost 220.996
# step 2030, change in cost 0.0686035
# step 2040, training accuracy 0.66107
# step 2040, cost 220.928
# step 2040, change in cost 0.0685425
# step 2050, training accuracy 0.66212
# step 2050, cost 220.859
# step 2050, change in cost 0.068512
# step 2060, training accuracy 0.664218
# step 2060, cost 220.791
# step 2060, change in cost 0.0684814
# step 2070, training accuracy 0.666317
# step 2070, cost 220.722
# step 2070, change in cost 0.0684357
# step 2080, training accuracy 0.666317
# step 2080, cost 220.654
# step 2080, change in cost 0.0683899
# step 2090, training accuracy 0.669465
# step 2090, cost 220.586
# step 2090, change in cost 0.0683289
# step 2100, training accuracy 0.669465
# step 2100, cost 220.517
# step 2100, change in cost 0.0683136
# step 2110, training accuracy 0.670514
# step 2110, cost 220.449
# step 2110, change in cost 0.0682831
# step 2120, training accuracy 0.670514
# step 2120, cost 220.381
# step 2120, change in cost 0.0682373
# step 2130, training accuracy 0.670514
# step 2130, cost 220.313
# step 2130, change in cost 0.0681305
# step 2140, training accuracy 0.670514
# step 2140, cost 220.245
# step 2140, change in cost 0.0681763
# step 2150, training accuracy 0.673662
# step 2150, cost 220.177
# step 2150, change in cost 0.0681
# step 2160, training accuracy 0.673662
# step 2160, cost 220.108
# step 2160, change in cost 0.0680695
# step 2170, training accuracy 0.673662
# step 2170, cost 220.04
# step 2170, change in cost 0.0680389
# step 2180, training accuracy 0.677859
# step 2180, cost 219.972
# step 2180, change in cost 0.0679779
# step 2190, training accuracy 0.678909
# step 2190, cost 219.904
# step 2190, change in cost 0.0679321
# step 2200, training accuracy 0.678909
# step 2200, cost 219.837
# step 2200, change in cost 0.0679016
# step 2210, training accuracy 0.678909
# step 2210, cost 219.769
# step 2210, change in cost 0.0678864
# step 2220, training accuracy 0.678909
# step 2220, cost 219.701
# step 2220, change in cost 0.0678253
# step 2230, training accuracy 0.678909
# step 2230, cost 219.633
# step 2230, change in cost 0.0677795
# step 2240, training accuracy 0.678909
# step 2240, cost 219.565
# step 2240, change in cost 0.067749
# step 2250, training accuracy 0.679958
# step 2250, cost 219.498
# step 2250, change in cost 0.0677185
# step 2260, training accuracy 0.681007
# step 2260, cost 219.43
# step 2260, change in cost 0.0676575
# step 2270, training accuracy 0.683106
# step 2270, cost 219.362
# step 2270, change in cost 0.067627
# step 2280, training accuracy 0.683106
# step 2280, cost 219.295
# step 2280, change in cost 0.0675659
# step 2290, training accuracy 0.685205
# step 2290, cost 219.227
# step 2290, change in cost 0.0675354
# step 2300, training accuracy 0.685205
# step 2300, cost 219.16
# step 2300, change in cost 0.0675354
# step 2310, training accuracy 0.687303
# step 2310, cost 219.092
# step 2310, change in cost 0.0674744
# step 2320, training accuracy 0.689402
# step 2320, cost 219.025
# step 2320, change in cost 0.0674591
# step 2330, training accuracy 0.689402
# step 2330, cost 218.957
# step 2330, change in cost 0.0673981
# step 2340, training accuracy 0.689402
# step 2340, cost 218.89
# step 2340, change in cost 0.0673065
# step 2350, training accuracy 0.689402
# step 2350, cost 218.823
# step 2350, change in cost 0.0672913
# step 2360, training accuracy 0.691501
# step 2360, cost 218.755
# step 2360, change in cost 0.0672913
# step 2370, training accuracy 0.691501
# step 2370, cost 218.688
# step 2370, change in cost 0.0672455
# step 2380, training accuracy 0.691501
# step 2380, cost 218.621
# step 2380, change in cost 0.0671692
# step 2390, training accuracy 0.694649
# step 2390, cost 218.554
# step 2390, change in cost 0.0671997
# step 2400, training accuracy 0.694649
# step 2400, cost 218.487
# step 2400, change in cost 0.0670776
# step 2410, training accuracy 0.694649
# step 2410, cost 218.42
# step 2410, change in cost 0.0670776
# step 2420, training accuracy 0.695698
# step 2420, cost 218.353
# step 2420, change in cost 0.0670471
# step 2430, training accuracy 0.695698
# step 2430, cost 218.286
# step 2430, change in cost 0.0669556
# step 2440, training accuracy 0.696747
# step 2440, cost 218.219
# step 2440, change in cost 0.0669708
# step 2450, training accuracy 0.697796
# step 2450, cost 218.152
# step 2450, change in cost 0.0669098
# step 2460, training accuracy 0.698846
# step 2460, cost 218.085
# step 2460, change in cost 0.0668945
# step 2470, training accuracy 0.699895
# step 2470, cost 218.018
# step 2470, change in cost 0.0668182
# step 2480, training accuracy 0.700944
# step 2480, cost 217.951
# step 2480, change in cost 0.0667877
# step 2490, training accuracy 0.700944
# step 2490, cost 217.885
# step 2490, change in cost 0.0667725
# step 2500, training accuracy 0.701994
# step 2500, cost 217.818
# step 2500, change in cost 0.0667114
# step 2510, training accuracy 0.703043
# step 2510, cost 217.751
# step 2510, change in cost 0.0667114
# step 2520, training accuracy 0.703043
# step 2520, cost 217.685
# step 2520, change in cost 0.0665894
# step 2530, training accuracy 0.704092
# step 2530, cost 217.618
# step 2530, change in cost 0.0666199
# step 2540, training accuracy 0.704092
# step 2540, cost 217.551
# step 2540, change in cost 0.0665588
# step 2550, training accuracy 0.704092
# step 2550, cost 217.485
# step 2550, change in cost 0.0664978
# step 2560, training accuracy 0.704092
# step 2560, cost 217.418
# step 2560, change in cost 0.0664978
# step 2570, training accuracy 0.705142
# step 2570, cost 217.352
# step 2570, change in cost 0.0664673
# step 2580, training accuracy 0.706191
# step 2580, cost 217.286
# step 2580, change in cost 0.0663757
# step 2590, training accuracy 0.709339
# step 2590, cost 217.219
# step 2590, change in cost 0.0663757
# step 2600, training accuracy 0.710388
# step 2600, cost 217.153
# step 2600, change in cost 0.0663452
# step 2610, training accuracy 0.712487
# step 2610, cost 217.087
# step 2610, change in cost 0.0662842
# step 2620, training accuracy 0.714586
# step 2620, cost 217.02
# step 2620, change in cost 0.0662231
# step 2630, training accuracy 0.714586
# step 2630, cost 216.954
# step 2630, change in cost 0.0662079
# step 2640, training accuracy 0.715635
# step 2640, cost 216.888
# step 2640, change in cost 0.0661774
# step 2650, training accuracy 0.716684
# step 2650, cost 216.822
# step 2650, change in cost 0.0661316
# step 2660, training accuracy 0.717734
# step 2660, cost 216.756
# step 2660, change in cost 0.0661316
# step 2670, training accuracy 0.717734
# step 2670, cost 216.69
# step 2670, change in cost 0.06604
# step 2680, training accuracy 0.719832
# step 2680, cost 216.624
# step 2680, change in cost 0.0659637
# step 2690, training accuracy 0.724029
# step 2690, cost 216.558
# step 2690, change in cost 0.0660095
# step 2700, training accuracy 0.724029
# step 2700, cost 216.492
# step 2700, change in cost 0.0659332
# step 2710, training accuracy 0.724029
# step 2710, cost 216.426
# step 2710, change in cost 0.0659027
# step 2720, training accuracy 0.724029
# step 2720, cost 216.36
# step 2720, change in cost 0.0658264
# step 2730, training accuracy 0.724029
# step 2730, cost 216.294
# step 2730, change in cost 0.0658722
# step 2740, training accuracy 0.724029
# step 2740, cost 216.228
# step 2740, change in cost 0.0657501
# step 2750, training accuracy 0.725079
# step 2750, cost 216.163
# step 2750, change in cost 0.0657959
# step 2760, training accuracy 0.725079
# step 2760, cost 216.097
# step 2760, change in cost 0.0656586
# step 2770, training accuracy 0.726128
# step 2770, cost 216.031
# step 2770, change in cost 0.0656738
# step 2780, training accuracy 0.726128
# step 2780, cost 215.966
# step 2780, change in cost 0.0655975
# step 2790, training accuracy 0.727177
# step 2790, cost 215.9
# step 2790, change in cost 0.0656128
# step 2800, training accuracy 0.728227
# step 2800, cost 215.835
# step 2800, change in cost 0.0655212
# step 2810, training accuracy 0.728227
# step 2810, cost 215.769
# step 2810, change in cost 0.0655365
# step 2820, training accuracy 0.728227
# step 2820, cost 215.703
# step 2820, change in cost 0.0654755
# step 2830, training accuracy 0.728227
# step 2830, cost 215.638
# step 2830, change in cost 0.0654449
# step 2840, training accuracy 0.729276
# step 2840, cost 215.573
# step 2840, change in cost 0.0653381
# step 2850, training accuracy 0.730325
# step 2850, cost 215.507
# step 2850, change in cost 0.0653992
# step 2860, training accuracy 0.731375
# step 2860, cost 215.442
# step 2860, change in cost 0.0653076
# step 2870, training accuracy 0.731375
# step 2870, cost 215.377
# step 2870, change in cost 0.0652771
# step 2880, training accuracy 0.731375
# step 2880, cost 215.311
# step 2880, change in cost 0.0652618
# step 2890, training accuracy 0.731375
# step 2890, cost 215.246
# step 2890, change in cost 0.0651855
# step 2900, training accuracy 0.732424
# step 2900, cost 215.181
# step 2900, change in cost 0.0651703
# step 2910, training accuracy 0.732424
# step 2910, cost 215.116
# step 2910, change in cost 0.0651093
# step 2920, training accuracy 0.732424
# step 2920, cost 215.051
# step 2920, change in cost 0.0650787
# step 2930, training accuracy 0.732424
# step 2930, cost 214.986
# step 2930, change in cost 0.0650482
# step 2940, training accuracy 0.733473
# step 2940, cost 214.921
# step 2940, change in cost 0.0649872
# step 2950, training accuracy 0.733473
# step 2950, cost 214.856
# step 2950, change in cost 0.0649719
# step 2960, training accuracy 0.734523
# step 2960, cost 214.791
# step 2960, change in cost 0.0649414
# step 2970, training accuracy 0.734523
# step 2970, cost 214.726
# step 2970, change in cost 0.0649109
# step 2980, training accuracy 0.734523
# step 2980, cost 214.661
# step 2980, change in cost 0.0648804
# step 2990, training accuracy 0.735572
# step 2990, cost 214.596
# step 2990, change in cost 0.0648193
# step 3000, training accuracy 0.735572
# step 3000, cost 214.532
# step 3000, change in cost 0.0647278
# step 3010, training accuracy 0.739769
# step 3010, cost 214.467
# step 3010, change in cost 0.0647736
# step 3020, training accuracy 0.739769
# step 3020, cost 214.402
# step 3020, change in cost 0.0646973
# step 3030, training accuracy 0.740818
# step 3030, cost 214.338
# step 3030, change in cost 0.0646515
# step 3040, training accuracy 0.740818
# step 3040, cost 214.273
# step 3040, change in cost 0.064621
# step 3050, training accuracy 0.740818
# step 3050, cost 214.208
# step 3050, change in cost 0.0646057
# step 3060, training accuracy 0.740818
# step 3060, cost 214.144
# step 3060, change in cost 0.0644989
# step 3070, training accuracy 0.740818
# step 3070, cost 214.079
# step 3070, change in cost 0.0645294
# step 3080, training accuracy 0.741868
# step 3080, cost 214.015
# step 3080, change in cost 0.0644684
# step 3090, training accuracy 0.742917
# step 3090, cost 213.95
# step 3090, change in cost 0.0644836
# step 3100, training accuracy 0.742917
# step 3100, cost 213.886
# step 3100, change in cost 0.0643616
# step 3110, training accuracy 0.742917
# step 3110, cost 213.822
# step 3110, change in cost 0.0643768
# step 3120, training accuracy 0.742917
# step 3120, cost 213.757
# step 3120, change in cost 0.0643311
# step 3130, training accuracy 0.742917
# step 3130, cost 213.693
# step 3130, change in cost 0.0643005
# step 3140, training accuracy 0.742917
# step 3140, cost 213.629
# step 3140, change in cost 0.064209
# step 3150, training accuracy 0.743966
# step 3150, cost 213.564
# step 3150, change in cost 0.0642548
# step 3160, training accuracy 0.745016
# step 3160, cost 213.5
# step 3160, change in cost 0.0641174
# step 3170, training accuracy 0.746065
# step 3170, cost 213.436
# step 3170, change in cost 0.0641174
# step 3180, training accuracy 0.746065
# step 3180, cost 213.372
# step 3180, change in cost 0.0641479
# step 3190, training accuracy 0.746065
# step 3190, cost 213.308
# step 3190, change in cost 0.0640259
# step 3200, training accuracy 0.748164
# step 3200, cost 213.244
# step 3200, change in cost 0.0639954
# step 3210, training accuracy 0.748164
# step 3210, cost 213.18
# step 3210, change in cost 0.0639801
# step 3220, training accuracy 0.748164
# step 3220, cost 213.116
# step 3220, change in cost 0.0639648
# step 3230, training accuracy 0.748164
# step 3230, cost 213.052
# step 3230, change in cost 0.0638733
# step 3240, training accuracy 0.750262
# step 3240, cost 212.988
# step 3240, change in cost 0.0639038
# step 3250, training accuracy 0.750262
# step 3250, cost 212.925
# step 3250, change in cost 0.0638123
# step 3260, training accuracy 0.752361
# step 3260, cost 212.861
# step 3260, change in cost 0.0637817
# step 3270, training accuracy 0.752361
# step 3270, cost 212.797
# step 3270, change in cost 0.0637512
# step 3280, training accuracy 0.75341
# step 3280, cost 212.733
# step 3280, change in cost 0.0637512
# step 3290, training accuracy 0.75446
# step 3290, cost 212.67
# step 3290, change in cost 0.0636902
# step 3300, training accuracy 0.755509
# step 3300, cost 212.606
# step 3300, change in cost 0.0636292
# step 3310, training accuracy 0.755509
# step 3310, cost 212.542
# step 3310, change in cost 0.0636139
# step 3320, training accuracy 0.755509
# step 3320, cost 212.479
# step 3320, change in cost 0.0635223
# step 3330, training accuracy 0.756558
# step 3330, cost 212.415
# step 3330, change in cost 0.0635223
# step 3340, training accuracy 0.757608
# step 3340, cost 212.352
# step 3340, change in cost 0.0635071
# step 3350, training accuracy 0.757608
# step 3350, cost 212.288
# step 3350, change in cost 0.0634766
# step 3360, training accuracy 0.757608
# step 3360, cost 212.225
# step 3360, change in cost 0.0633698
# step 3370, training accuracy 0.758657
# step 3370, cost 212.161
# step 3370, change in cost 0.0634155
# step 3380, training accuracy 0.759706
# step 3380, cost 212.098
# step 3380, change in cost 0.063324
# step 3390, training accuracy 0.759706
# step 3390, cost 212.035
# step 3390, change in cost 0.063324
# step 3400, training accuracy 0.759706
# step 3400, cost 211.972
# step 3400, change in cost 0.0632477
# step 3410, training accuracy 0.759706
# step 3410, cost 211.908
# step 3410, change in cost 0.0632477
# step 3420, training accuracy 0.760755
# step 3420, cost 211.845
# step 3420, change in cost 0.0631561
# step 3430, training accuracy 0.761805
# step 3430, cost 211.782
# step 3430, change in cost 0.0632019
# step 3440, training accuracy 0.762854
# step 3440, cost 211.719
# step 3440, change in cost 0.0630798
# step 3450, training accuracy 0.762854
# step 3450, cost 211.656
# step 3450, change in cost 0.0630951
# step 3460, training accuracy 0.762854
# step 3460, cost 211.593
# step 3460, change in cost 0.0630646
# step 3470, training accuracy 0.762854
# step 3470, cost 211.53
# step 3470, change in cost 0.062973
# step 3480, training accuracy 0.762854
# step 3480, cost 211.467
# step 3480, change in cost 0.0630035
# step 3490, training accuracy 0.762854
# step 3490, cost 211.404
# step 3490, change in cost 0.062912
# step 3500, training accuracy 0.762854
# step 3500, cost 211.341
# step 3500, change in cost 0.0628967
# step 3510, training accuracy 0.763903
# step 3510, cost 211.278
# step 3510, change in cost 0.0628357
# step 3520, training accuracy 0.763903
# step 3520, cost 211.215
# step 3520, change in cost 0.0628204
# step 3530, training accuracy 0.766002
# step 3530, cost 211.153
# step 3530, change in cost 0.0627747
# step 3540, training accuracy 0.766002
# step 3540, cost 211.09
# step 3540, change in cost 0.0627441
# step 3550, training accuracy 0.766002
# step 3550, cost 211.027
# step 3550, change in cost 0.0627136
# step 3560, training accuracy 0.767051
# step 3560, cost 210.964
# step 3560, change in cost 0.0626831
# step 3570, training accuracy 0.768101
# step 3570, cost 210.902
# step 3570, change in cost 0.0626373
# step 3580, training accuracy 0.76915
# step 3580, cost 210.839
# step 3580, change in cost 0.0625916
# step 3590, training accuracy 0.76915
# step 3590, cost 210.777
# step 3590, change in cost 0.0625916
# step 3600, training accuracy 0.770199
# step 3600, cost 210.714
# step 3600, change in cost 0.0625153
# step 3610, training accuracy 0.771249
# step 3610, cost 210.652
# step 3610, change in cost 0.0624695
# step 3620, training accuracy 0.772298
# step 3620, cost 210.589
# step 3620, change in cost 0.0624542
# step 3630, training accuracy 0.773347
# step 3630, cost 210.527
# step 3630, change in cost 0.0623932
# step 3640, training accuracy 0.773347
# step 3640, cost 210.464
# step 3640, change in cost 0.0624237
# step 3650, training accuracy 0.774397
# step 3650, cost 210.402
# step 3650, change in cost 0.0623016
# step 3660, training accuracy 0.774397
# step 3660, cost 210.34
# step 3660, change in cost 0.0623322
# step 3670, training accuracy 0.775446
# step 3670, cost 210.277
# step 3670, change in cost 0.0622406
# step 3680, training accuracy 0.775446
# step 3680, cost 210.215
# step 3680, change in cost 0.0622406
# step 3690, training accuracy 0.775446
# step 3690, cost 210.153
# step 3690, change in cost 0.0621948
# step 3700, training accuracy 0.775446
# step 3700, cost 210.091
# step 3700, change in cost 0.0621643
# step 3710, training accuracy 0.776495
# step 3710, cost 210.029
# step 3710, change in cost 0.0620728
# step 3720, training accuracy 0.776495
# step 3720, cost 209.967
# step 3720, change in cost 0.0621185
# step 3730, training accuracy 0.776495
# step 3730, cost 209.905
# step 3730, change in cost 0.0620728
# step 3740, training accuracy 0.776495
# step 3740, cost 209.843
# step 3740, change in cost 0.0619812
# step 3750, training accuracy 0.777545
# step 3750, cost 209.781
# step 3750, change in cost 0.0619659
# step 3760, training accuracy 0.777545
# step 3760, cost 209.719
# step 3760, change in cost 0.0619965
# step 3770, training accuracy 0.778594
# step 3770, cost 209.657
# step 3770, change in cost 0.0618591
# step 3780, training accuracy 0.778594
# step 3780, cost 209.595
# step 3780, change in cost 0.0618591
# step 3790, training accuracy 0.778594
# step 3790, cost 209.533
# step 3790, change in cost 0.0617828
# step 3800, training accuracy 0.778594
# step 3800, cost 209.471
# step 3800, change in cost 0.0618134
# step 3810, training accuracy 0.779643
# step 3810, cost 209.41
# step 3810, change in cost 0.0617828
# step 3820, training accuracy 0.780693
# step 3820, cost 209.348
# step 3820, change in cost 0.0617218
# step 3830, training accuracy 0.780693
# step 3830, cost 209.286
# step 3830, change in cost 0.0616913
# step 3840, training accuracy 0.780693
# step 3840, cost 209.225
# step 3840, change in cost 0.061615
# step 3850, training accuracy 0.78384
# step 3850, cost 209.163
# step 3850, change in cost 0.0616455
# step 3860, training accuracy 0.78384
# step 3860, cost 209.101
# step 3860, change in cost 0.0615234
# step 3870, training accuracy 0.78489
# step 3870, cost 209.04
# step 3870, change in cost 0.0615692
# step 3880, training accuracy 0.78489
# step 3880, cost 208.978
# step 3880, change in cost 0.0614777
# step 3890, training accuracy 0.785939
# step 3890, cost 208.917
# step 3890, change in cost 0.0614624
# step 3900, training accuracy 0.785939
# step 3900, cost 208.855
# step 3900, change in cost 0.0614319
# step 3910, training accuracy 0.785939
# step 3910, cost 208.794
# step 3910, change in cost 0.0613861
# step 3920, training accuracy 0.785939
# step 3920, cost 208.733
# step 3920, change in cost 0.0613403
# step 3930, training accuracy 0.786988
# step 3930, cost 208.671
# step 3930, change in cost 0.0613556
# step 3940, training accuracy 0.788038
# step 3940, cost 208.61
# step 3940, change in cost 0.0612793
# step 3950, training accuracy 0.788038
# step 3950, cost 208.549
# step 3950, change in cost 0.0612488
# step 3960, training accuracy 0.788038
# step 3960, cost 208.488
# step 3960, change in cost 0.061203
# step 3970, training accuracy 0.791186
# step 3970, cost 208.426
# step 3970, change in cost 0.0611572
# step 3980, training accuracy 0.792235
# step 3980, cost 208.365
# step 3980, change in cost 0.0611267
# step 3990, training accuracy 0.793284
# step 3990, cost 208.304
# step 3990, change in cost 0.0611115
# step 4000, training accuracy 0.793284
# step 4000, cost 208.243
# step 4000, change in cost 0.0610809
# step 4010, training accuracy 0.793284
# step 4010, cost 208.182
# step 4010, change in cost 0.0610352
# step 4020, training accuracy 0.793284
# step 4020, cost 208.121
# step 4020, change in cost 0.0609741
# step 4030, training accuracy 0.793284
# step 4030, cost 208.06
# step 4030, change in cost 0.0609894
# step 4040, training accuracy 0.793284
# step 4040, cost 207.999
# step 4040, change in cost 0.0609436
# step 4050, training accuracy 0.795383
# step 4050, cost 207.938
# step 4050, change in cost 0.0608215
# step 4060, training accuracy 0.795383
# step 4060, cost 207.877
# step 4060, change in cost 0.0608673
# step 4070, training accuracy 0.796432
# step 4070, cost 207.817
# step 4070, change in cost 0.060791
# step 4080, training accuracy 0.797482
# step 4080, cost 207.756
# step 4080, change in cost 0.0608368
# step 4090, training accuracy 0.79958
# step 4090, cost 207.695
# step 4090, change in cost 0.0606842
# step 4100, training accuracy 0.80063
# step 4100, cost 207.634
# step 4100, change in cost 0.06073
# step 4110, training accuracy 0.80063
# step 4110, cost 207.574
# step 4110, change in cost 0.0607147
# step 4120, training accuracy 0.80063
# step 4120, cost 207.513
# step 4120, change in cost 0.0606079
# step 4130, training accuracy 0.80063
# step 4130, cost 207.453
# step 4130, change in cost 0.0606079
# step 4140, training accuracy 0.80063
# step 4140, cost 207.392
# step 4140, change in cost 0.0605316
# step 4150, training accuracy 0.80063
# step 4150, cost 207.331
# step 4150, change in cost 0.0605621
# step 4160, training accuracy 0.80063
# step 4160, cost 207.271
# step 4160, change in cost 0.0604553
# step 4170, training accuracy 0.80063
# step 4170, cost 207.21
# step 4170, change in cost 0.0604706
# step 4180, training accuracy 0.80063
# step 4180, cost 207.15
# step 4180, change in cost 0.0604553
# step 4190, training accuracy 0.80063
# step 4190, cost 207.09
# step 4190, change in cost 0.0603638
# step 4200, training accuracy 0.80063
# step 4200, cost 207.029
# step 4200, change in cost 0.0603485
# step 4210, training accuracy 0.80063
# step 4210, cost 206.969
# step 4210, change in cost 0.0603333
# step 4220, training accuracy 0.801679
# step 4220, cost 206.909
# step 4220, change in cost 0.060257
# step 4230, training accuracy 0.801679
# step 4230, cost 206.848
# step 4230, change in cost 0.0602417
# step 4240, training accuracy 0.801679
# step 4240, cost 206.788
# step 4240, change in cost 0.0601959
# step 4250, training accuracy 0.802728
# step 4250, cost 206.728
# step 4250, change in cost 0.0601501
# step 4260, training accuracy 0.803778
# step 4260, cost 206.668
# step 4260, change in cost 0.0601654
# step 4270, training accuracy 0.803778
# step 4270, cost 206.608
# step 4270, change in cost 0.0600891
# step 4280, training accuracy 0.804827
# step 4280, cost 206.548
# step 4280, change in cost 0.0601044
# step 4290, training accuracy 0.804827
# step 4290, cost 206.488
# step 4290, change in cost 0.0600281
# step 4300, training accuracy 0.805876
# step 4300, cost 206.428
# step 4300, change in cost 0.0600128
# step 4310, training accuracy 0.806925
# step 4310, cost 206.368
# step 4310, change in cost 0.0599823
# step 4320, training accuracy 0.806925
# step 4320, cost 206.308
# step 4320, change in cost 0.059906
# step 4330, training accuracy 0.806925
# step 4330, cost 206.248
# step 4330, change in cost 0.0598755
# step 4340, training accuracy 0.809024
# step 4340, cost 206.188
# step 4340, change in cost 0.0598755
# step 4350, training accuracy 0.809024
# step 4350, cost 206.128
# step 4350, change in cost 0.0597839
# step 4360, training accuracy 0.809024
# step 4360, cost 206.069
# step 4360, change in cost 0.0597992
# step 4370, training accuracy 0.811123
# step 4370, cost 206.009
# step 4370, change in cost 0.0597534
# step 4380, training accuracy 0.811123
# step 4380, cost 205.949
# step 4380, change in cost 0.0597382
# step 4390, training accuracy 0.811123
# step 4390, cost 205.889
# step 4390, change in cost 0.0596619
# step 4400, training accuracy 0.813221
# step 4400, cost 205.83
# step 4400, change in cost 0.0596313
# step 4410, training accuracy 0.813221
# step 4410, cost 205.77
# step 4410, change in cost 0.0596161
# step 4420, training accuracy 0.813221
# step 4420, cost 205.711
# step 4420, change in cost 0.0595856
# step 4430, training accuracy 0.813221
# step 4430, cost 205.651
# step 4430, change in cost 0.0595398
# step 4440, training accuracy 0.813221
# step 4440, cost 205.591
# step 4440, change in cost 0.0595093
# step 4450, training accuracy 0.814271
# step 4450, cost 205.532
# step 4450, change in cost 0.0594788
# step 4460, training accuracy 0.814271
# step 4460, cost 205.473
# step 4460, change in cost 0.0594177
# step 4470, training accuracy 0.814271
# step 4470, cost 205.413
# step 4470, change in cost 0.0594482
# step 4480, training accuracy 0.814271
# step 4480, cost 205.354
# step 4480, change in cost 0.0593414
# step 4490, training accuracy 0.814271
# step 4490, cost 205.295
# step 4490, change in cost 0.0592957
# step 4500, training accuracy 0.814271
# step 4500, cost 205.235
# step 4500, change in cost 0.0593109
# step 4510, training accuracy 0.814271
# step 4510, cost 205.176
# step 4510, change in cost 0.0592957
# step 4520, training accuracy 0.81532
# step 4520, cost 205.117
# step 4520, change in cost 0.0591888
# step 4530, training accuracy 0.816369
# step 4530, cost 205.057
# step 4530, change in cost 0.0592194
# step 4540, training accuracy 0.817419
# step 4540, cost 204.998
# step 4540, change in cost 0.0591278
# step 4550, training accuracy 0.818468
# step 4550, cost 204.939
# step 4550, change in cost 0.0591431
# step 4560, training accuracy 0.818468
# step 4560, cost 204.88
# step 4560, change in cost 0.059082
# step 4570, training accuracy 0.818468
# step 4570, cost 204.821
# step 4570, change in cost 0.0590668
# step 4580, training accuracy 0.819517
# step 4580, cost 204.762
# step 4580, change in cost 0.0590057
# step 4590, training accuracy 0.819517
# step 4590, cost 204.703
# step 4590, change in cost 0.0589905
# step 4600, training accuracy 0.819517
# step 4600, cost 204.644
# step 4600, change in cost 0.0589294
# step 4610, training accuracy 0.820567
# step 4610, cost 204.585
# step 4610, change in cost 0.0589142
# step 4620, training accuracy 0.821616
# step 4620, cost 204.526
# step 4620, change in cost 0.0588684
# step 4630, training accuracy 0.823715
# step 4630, cost 204.467
# step 4630, change in cost 0.0588684
# step 4640, training accuracy 0.824764
# step 4640, cost 204.409
# step 4640, change in cost 0.0587769
# step 4650, training accuracy 0.825813
# step 4650, cost 204.35
# step 4650, change in cost 0.0588226
# step 4660, training accuracy 0.825813
# step 4660, cost 204.291
# step 4660, change in cost 0.0587463
# step 4670, training accuracy 0.825813
# step 4670, cost 204.232
# step 4670, change in cost 0.0586853
# step 4680, training accuracy 0.826863
# step 4680, cost 204.174
# step 4680, change in cost 0.05867
# step 4690, training accuracy 0.826863
# step 4690, cost 204.115
# step 4690, change in cost 0.0586395
# step 4700, training accuracy 0.826863
# step 4700, cost 204.057
# step 4700, change in cost 0.0585785
# step 4710, training accuracy 0.826863
# step 4710, cost 203.998
# step 4710, change in cost 0.0585938
# step 4720, training accuracy 0.826863
# step 4720, cost 203.939
# step 4720, change in cost 0.0585632
# step 4730, training accuracy 0.826863
# step 4730, cost 203.881
# step 4730, change in cost 0.0584717
# step 4740, training accuracy 0.826863
# step 4740, cost 203.823
# step 4740, change in cost 0.0584412
# step 4750, training accuracy 0.826863
# step 4750, cost 203.764
# step 4750, change in cost 0.0584564
# step 4760, training accuracy 0.827912
# step 4760, cost 203.706
# step 4760, change in cost 0.0583954
# step 4770, training accuracy 0.828961
# step 4770, cost 203.647
# step 4770, change in cost 0.0583801
# step 4780, training accuracy 0.83001
# step 4780, cost 203.589
# step 4780, change in cost 0.0583344
# step 4790, training accuracy 0.83001
# step 4790, cost 203.531
# step 4790, change in cost 0.0582886
# step 4800, training accuracy 0.83001
# step 4800, cost 203.472
# step 4800, change in cost 0.0582428
# step 4810, training accuracy 0.83001
# step 4810, cost 203.414
# step 4810, change in cost 0.0582733
# step 4820, training accuracy 0.83001
# step 4820, cost 203.356
# step 4820, change in cost 0.0581818
# step 4830, training accuracy 0.83001
# step 4830, cost 203.298
# step 4830, change in cost 0.0581665
# step 4840, training accuracy 0.83001
# step 4840, cost 203.24
# step 4840, change in cost 0.0580902
# step 4850, training accuracy 0.83106
# step 4850, cost 203.182
# step 4850, change in cost 0.058075
# step 4860, training accuracy 0.83106
# step 4860, cost 203.124
# step 4860, change in cost 0.0581207
# step 4870, training accuracy 0.832109
# step 4870, cost 203.066
# step 4870, change in cost 0.0579681
# step 4880, training accuracy 0.832109
# step 4880, cost 203.008
# step 4880, change in cost 0.0580139
# step 4890, training accuracy 0.832109
# step 4890, cost 202.95
# step 4890, change in cost 0.0579376
# step 4900, training accuracy 0.832109
# step 4900, cost 202.892
# step 4900, change in cost 0.0579376
# step 4910, training accuracy 0.832109
# step 4910, cost 202.834
# step 4910, change in cost 0.0579071
# step 4920, training accuracy 0.832109
# step 4920, cost 202.776
# step 4920, change in cost 0.0578003
# step 4930, training accuracy 0.832109
# step 4930, cost 202.718
# step 4930, change in cost 0.0578461
# step 4940, training accuracy 0.832109
# step 4940, cost 202.66
# ...
# step 18410, cost 147.537
# step 18410, change in cost 0.028717
# step 18420, training accuracy 0.952781
# step 18420, cost 147.509
# step 18420, change in cost 0.0287628
# step 18430, training accuracy 0.952781
# step 18430, cost 147.48
# step 18430, change in cost 0.0286865
# step 18440, training accuracy 0.952781
# step 18440, cost 147.451
# step 18440, change in cost 0.0287476
# step 18450, training accuracy 0.952781
# step 18450, cost 147.423
# step 18450, change in cost 0.0287018
# step 18460, training accuracy 0.952781
# step 18460, cost 147.394
# step 18460, change in cost 0.0286865
# step 18470, training accuracy 0.952781
# step 18470, cost 147.365
# step 18470, change in cost 0.0286407
# step 18480, training accuracy 0.952781
# step 18480, cost 147.337
# step 18480, change in cost 0.0286865
# step 18490, training accuracy 0.952781
# step 18490, cost 147.308
# step 18490, change in cost 0.028656
# step 18500, training accuracy 0.952781
# step 18500, cost 147.279
# step 18500, change in cost 0.0286102
# step 18510, training accuracy 0.952781
# step 18510, cost 147.251
# step 18510, change in cost 0.0286255
# step 18520, training accuracy 0.952781
# step 18520, cost 147.222
# step 18520, change in cost 0.0286255
# step 18530, training accuracy 0.952781
# step 18530, cost 147.193
# step 18530, change in cost 0.028595
# step 18540, training accuracy 0.952781
# step 18540, cost 147.165
# step 18540, change in cost 0.028595
# step 18550, training accuracy 0.952781
# step 18550, cost 147.136
# step 18550, change in cost 0.0285339
# step 18560, training accuracy 0.952781
# step 18560, cost 147.108
# step 18560, change in cost 0.028595
# step 18570, training accuracy 0.952781
# step 18570, cost 147.079
# step 18570, change in cost 0.0285034
# step 18580, training accuracy 0.952781
# step 18580, cost 147.051
# step 18580, change in cost 0.0285797
# step 18590, training accuracy 0.952781
# step 18590, cost 147.022
# step 18590, change in cost 0.0284882
# step 18600, training accuracy 0.952781
# step 18600, cost 146.994
# step 18600, change in cost 0.0285492
# step 18610, training accuracy 0.952781
# step 18610, cost 146.965
# step 18610, change in cost 0.0284882
# step 18620, training accuracy 0.952781
# step 18620, cost 146.937
# step 18620, change in cost 0.0284729
# step 18630, training accuracy 0.952781
# step 18630, cost 146.908
# step 18630, change in cost 0.0284729
# step 18640, training accuracy 0.952781
# step 18640, cost 146.88
# step 18640, change in cost 0.0284271
# step 18650, training accuracy 0.952781
# step 18650, cost 146.851
# step 18650, change in cost 0.0284576
# step 18660, training accuracy 0.952781
# step 18660, cost 146.823
# step 18660, change in cost 0.0284271
# step 18670, training accuracy 0.952781
# step 18670, cost 146.794
# step 18670, change in cost 0.0284576
# step 18680, training accuracy 0.952781
# step 18680, cost 146.766
# step 18680, change in cost 0.0283966
# step 18690, training accuracy 0.952781
# step 18690, cost 146.738
# step 18690, change in cost 0.0283661
# step 18700, training accuracy 0.952781
# step 18700, cost 146.709
# step 18700, change in cost 0.0284119
# step 18710, training accuracy 0.952781
# step 18710, cost 146.681
# step 18710, change in cost 0.0283356
# step 18720, training accuracy 0.952781
# step 18720, cost 146.653
# step 18720, change in cost 0.0283508
# step 18730, training accuracy 0.952781
# step 18730, cost 146.624
# step 18730, change in cost 0.0283508
# step 18740, training accuracy 0.952781
# step 18740, cost 146.596
# step 18740, change in cost 0.0283356
# step 18750, training accuracy 0.952781
# step 18750, cost 146.568
# step 18750, change in cost 0.0283508
# step 18760, training accuracy 0.952781
# step 18760, cost 146.539
# step 18760, change in cost 0.0283051
# step 18770, training accuracy 0.952781
# step 18770, cost 146.511
# step 18770, change in cost 0.0282745
# step 18780, training accuracy 0.952781
# step 18780, cost 146.483
# step 18780, change in cost 0.0282898
# step 18790, training accuracy 0.952781
# step 18790, cost 146.454
# step 18790, change in cost 0.0282288
# step 18800, training accuracy 0.952781
# step 18800, cost 146.426
# step 18800, change in cost 0.0282898
# step 18810, training accuracy 0.952781
# step 18810, cost 146.398
# step 18810, change in cost 0.028244
# step 18820, training accuracy 0.952781
# step 18820, cost 146.37
# step 18820, change in cost 0.0282135
# step 18830, training accuracy 0.952781
# step 18830, cost 146.341
# step 18830, change in cost 0.028244
# step 18840, training accuracy 0.952781
# step 18840, cost 146.313
# step 18840, change in cost 0.028183
# step 18850, training accuracy 0.952781
# step 18850, cost 146.285
# step 18850, change in cost 0.028183
# step 18860, training accuracy 0.952781
# step 18860, cost 146.257
# step 18860, change in cost 0.028183
# step 18870, training accuracy 0.952781
# step 18870, cost 146.229
# step 18870, change in cost 0.0281982
# step 18880, training accuracy 0.952781
# step 18880, cost 146.201
# step 18880, change in cost 0.0281372
# step 18890, training accuracy 0.952781
# step 18890, cost 146.172
# step 18890, change in cost 0.0281525
# step 18900, training accuracy 0.952781
# step 18900, cost 146.144
# step 18900, change in cost 0.0281219
# step 18910, training accuracy 0.952781
# step 18910, cost 146.116
# step 18910, change in cost 0.0281219
# step 18920, training accuracy 0.952781
# step 18920, cost 146.088
# step 18920, change in cost 0.0280914
# step 18930, training accuracy 0.952781
# step 18930, cost 146.06
# step 18930, change in cost 0.0281067
# step 18940, training accuracy 0.952781
# step 18940, cost 146.032
# step 18940, change in cost 0.0280914
# step 18950, training accuracy 0.952781
# step 18950, cost 146.004
# step 18950, change in cost 0.0280457
# step 18960, training accuracy 0.952781
# step 18960, cost 145.976
# step 18960, change in cost 0.0280762
# step 18970, training accuracy 0.952781
# step 18970, cost 145.948
# step 18970, change in cost 0.0280304
# step 18980, training accuracy 0.952781
# step 18980, cost 145.92
# step 18980, change in cost 0.0280457
# step 18990, training accuracy 0.952781
# step 18990, cost 145.892
# step 18990, change in cost 0.0280304
# step 19000, training accuracy 0.952781
# step 19000, cost 145.864
# step 19000, change in cost 0.0279999
# step 19010, training accuracy 0.952781
# step 19010, cost 145.836
# step 19010, change in cost 0.0279999
# step 19020, training accuracy 0.952781
# step 19020, cost 145.808
# step 19020, change in cost 0.0279694
# step 19030, training accuracy 0.952781
# step 19030, cost 145.78
# step 19030, change in cost 0.0279846
# step 19040, training accuracy 0.952781
# step 19040, cost 145.752
# step 19040, change in cost 0.0279541
# step 19050, training accuracy 0.952781
# step 19050, cost 145.724
# step 19050, change in cost 0.0279388
# step 19060, training accuracy 0.952781
# step 19060, cost 145.696
# step 19060, change in cost 0.0279083
# step 19070, training accuracy 0.95383
# step 19070, cost 145.668
# step 19070, change in cost 0.0279236
# step 19080, training accuracy 0.95383
# step 19080, cost 145.64
# step 19080, change in cost 0.0279083
# step 19090, training accuracy 0.95383
# step 19090, cost 145.612
# step 19090, change in cost 0.0278931
# step 19100, training accuracy 0.95383
# step 19100, cost 145.584
# step 19100, change in cost 0.0278931
# step 19110, training accuracy 0.95383
# step 19110, cost 145.556
# step 19110, change in cost 0.0278778
# step 19120, training accuracy 0.95383
# step 19120, cost 145.528
# step 19120, change in cost 0.0278931
# step 19130, training accuracy 0.95383
# step 19130, cost 145.501
# step 19130, change in cost 0.027832
# step 19140, training accuracy 0.95383
# step 19140, cost 145.473
# step 19140, change in cost 0.0278168
# step 19150, training accuracy 0.95383
# step 19150, cost 145.445
# step 19150, change in cost 0.0278168
# step 19160, training accuracy 0.95383
# step 19160, cost 145.417
# step 19160, change in cost 0.0278168
# step 19170, training accuracy 0.95383
# step 19170, cost 145.389
# step 19170, change in cost 0.027771
# step 19180, training accuracy 0.95383
# step 19180, cost 145.362
# step 19180, change in cost 0.0278015
# step 19190, training accuracy 0.95383
# step 19190, cost 145.334
# step 19190, change in cost 0.027771
# step 19200, training accuracy 0.95383
# step 19200, cost 145.306
# step 19200, change in cost 0.0277863
# step 19210, training accuracy 0.95383
# step 19210, cost 145.278
# step 19210, change in cost 0.027771
# step 19220, training accuracy 0.95383
# step 19220, cost 145.251
# step 19220, change in cost 0.02771
# step 19230, training accuracy 0.95383
# step 19230, cost 145.223
# step 19230, change in cost 0.0276947
# step 19240, training accuracy 0.95383
# step 19240, cost 145.195
# step 19240, change in cost 0.0277252
# step 19250, training accuracy 0.95383
# step 19250, cost 145.167
# step 19250, change in cost 0.0277405
# step 19260, training accuracy 0.95383
# step 19260, cost 145.14
# step 19260, change in cost 0.0276642
# step 19270, training accuracy 0.95383
# step 19270, cost 145.112
# step 19270, change in cost 0.0276642
# step 19280, training accuracy 0.95383
# step 19280, cost 145.084
# step 19280, change in cost 0.0276794
# step 19290, training accuracy 0.95383
# step 19290, cost 145.057
# step 19290, change in cost 0.0276489
# step 19300, training accuracy 0.95383
# step 19300, cost 145.029
# step 19300, change in cost 0.0276337
# step 19310, training accuracy 0.95383
# step 19310, cost 145.002
# step 19310, change in cost 0.0276184
# step 19320, training accuracy 0.95383
# step 19320, cost 144.974
# step 19320, change in cost 0.0276184
# step 19330, training accuracy 0.95383
# step 19330, cost 144.946
# step 19330, change in cost 0.0276337
# step 19340, training accuracy 0.95383
# step 19340, cost 144.919
# step 19340, change in cost 0.0275879
# step 19350, training accuracy 0.95383
# step 19350, cost 144.891
# step 19350, change in cost 0.0275574
# step 19360, training accuracy 0.95383
# step 19360, cost 144.864
# step 19360, change in cost 0.0276031
# step 19370, training accuracy 0.95383
# step 19370, cost 144.836
# step 19370, change in cost 0.0275421
# step 19380, training accuracy 0.95383
# step 19380, cost 144.808
# step 19380, change in cost 0.0275574
# step 19390, training accuracy 0.95383
# step 19390, cost 144.781
# step 19390, change in cost 0.0274811
# step 19400, training accuracy 0.95383
# step 19400, cost 144.753
# step 19400, change in cost 0.0275421
# step 19410, training accuracy 0.95383
# step 19410, cost 144.726
# step 19410, change in cost 0.0275116
# step 19420, training accuracy 0.954879
# step 19420, cost 144.698
# step 19420, change in cost 0.0275116
# step 19430, training accuracy 0.954879
# step 19430, cost 144.671
# step 19430, change in cost 0.0274811
# step 19440, training accuracy 0.954879
# step 19440, cost 144.643
# step 19440, change in cost 0.0274811
# step 19450, training accuracy 0.955929
# step 19450, cost 144.616
# step 19450, change in cost 0.0274506
# step 19460, training accuracy 0.955929
# step 19460, cost 144.589
# step 19460, change in cost 0.02742
# step 19470, training accuracy 0.955929
# step 19470, cost 144.561
# step 19470, change in cost 0.0274658
# step 19480, training accuracy 0.955929
# step 19480, cost 144.534
# step 19480, change in cost 0.0273895
# step 19490, training accuracy 0.955929
# step 19490, cost 144.506
# step 19490, change in cost 0.02742
# step 19500, training accuracy 0.955929
# step 19500, cost 144.479
# step 19500, change in cost 0.0274048
# step 19510, training accuracy 0.955929
# step 19510, cost 144.451
# step 19510, change in cost 0.0274048
# step 19520, training accuracy 0.955929
# step 19520, cost 144.424
# step 19520, change in cost 0.0273438
# step 19530, training accuracy 0.955929
# step 19530, cost 144.397
# step 19530, change in cost 0.0273743
# step 19540, training accuracy 0.955929
# step 19540, cost 144.369
# step 19540, change in cost 0.027359
# step 19550, training accuracy 0.955929
# step 19550, cost 144.342
# step 19550, change in cost 0.0273438
# step 19560, training accuracy 0.955929
# step 19560, cost 144.315
# step 19560, change in cost 0.0273132
# step 19570, training accuracy 0.955929
# step 19570, cost 144.287
# step 19570, change in cost 0.0273285
# step 19580, training accuracy 0.955929
# step 19580, cost 144.26
# step 19580, change in cost 0.027298
# step 19590, training accuracy 0.955929
# step 19590, cost 144.233
# step 19590, change in cost 0.027298
# step 19600, training accuracy 0.955929
# step 19600, cost 144.206
# step 19600, change in cost 0.027298
# step 19610, training accuracy 0.955929
# step 19610, cost 144.178
# step 19610, change in cost 0.0272522
# step 19620, training accuracy 0.955929
# step 19620, cost 144.151
# step 19620, change in cost 0.0272827
# step 19630, training accuracy 0.955929
# step 19630, cost 144.124
# step 19630, change in cost 0.0272217
# step 19640, training accuracy 0.955929
# step 19640, cost 144.096
# step 19640, change in cost 0.0272675
# step 19650, training accuracy 0.955929
# step 19650, cost 144.069
# step 19650, change in cost 0.0271759
# step 19660, training accuracy 0.955929
# step 19660, cost 144.042
# step 19660, change in cost 0.0272522
# step 19670, training accuracy 0.955929
# step 19670, cost 144.015
# step 19670, change in cost 0.0271759
# step 19680, training accuracy 0.955929
# step 19680, cost 143.988
# step 19680, change in cost 0.0271606
# step 19690, training accuracy 0.955929
# step 19690, cost 143.961
# step 19690, change in cost 0.0272064
# step 19700, training accuracy 0.955929
# step 19700, cost 143.933
# step 19700, change in cost 0.0271454
# step 19710, training accuracy 0.955929
# step 19710, cost 143.906
# step 19710, change in cost 0.0271454
# step 19720, training accuracy 0.955929
# step 19720, cost 143.879
# step 19720, change in cost 0.0271454
# step 19730, training accuracy 0.955929
# step 19730, cost 143.852
# step 19730, change in cost 0.0271149
# step 19740, training accuracy 0.955929
# step 19740, cost 143.825
# step 19740, change in cost 0.0271301
# step 19750, training accuracy 0.955929
# step 19750, cost 143.798
# step 19750, change in cost 0.0270844
# step 19760, training accuracy 0.955929
# step 19760, cost 143.771
# step 19760, change in cost 0.0270996
# step 19770, training accuracy 0.956978
# step 19770, cost 143.744
# step 19770, change in cost 0.0270844
# step 19780, training accuracy 0.956978
# step 19780, cost 143.716
# step 19780, change in cost 0.0270691
# step 19790, training accuracy 0.956978
# step 19790, cost 143.689
# step 19790, change in cost 0.0270538
# step 19800, training accuracy 0.956978
# step 19800, cost 143.662
# step 19800, change in cost 0.0270691
# step 19810, training accuracy 0.956978
# step 19810, cost 143.635
# step 19810, change in cost 0.0269928
# step 19820, training accuracy 0.956978
# step 19820, cost 143.608
# step 19820, change in cost 0.0270386
# step 19830, training accuracy 0.956978
# step 19830, cost 143.581
# step 19830, change in cost 0.0269928
# step 19840, training accuracy 0.956978
# step 19840, cost 143.554
# step 19840, change in cost 0.0270386
# step 19850, training accuracy 0.956978
# step 19850, cost 143.527
# step 19850, change in cost 0.0269775
# step 19860, training accuracy 0.956978
# step 19860, cost 143.5
# step 19860, change in cost 0.026947
# step 19870, training accuracy 0.956978
# step 19870, cost 143.473
# step 19870, change in cost 0.0269775
# step 19880, training accuracy 0.958027
# step 19880, cost 143.446
# step 19880, change in cost 0.0269318
# step 19890, training accuracy 0.958027
# step 19890, cost 143.42
# step 19890, change in cost 0.026947
# step 19900, training accuracy 0.958027
# step 19900, cost 143.393
# step 19900, change in cost 0.0269165
# step 19910, training accuracy 0.958027
# step 19910, cost 143.366
# step 19910, change in cost 0.026947
# step 19920, training accuracy 0.958027
# step 19920, cost 143.339
# step 19920, change in cost 0.0268707
# step 19930, training accuracy 0.958027
# step 19930, cost 143.312
# step 19930, change in cost 0.026886
# step 19940, training accuracy 0.958027
# step 19940, cost 143.285
# step 19940, change in cost 0.026886
# step 19950, training accuracy 0.958027
# step 19950, cost 143.258
# step 19950, change in cost 0.026886
# step 19960, training accuracy 0.958027
# step 19960, cost 143.231
# step 19960, change in cost 0.026825
# step 19970, training accuracy 0.958027
# step 19970, cost 143.204
# step 19970, change in cost 0.0268707
# step 19980, training accuracy 0.958027
# step 19980, cost 143.178
# step 19980, change in cost 0.0268402
# step 19990, training accuracy 0.958027
# step 19990, cost 143.151
# step 19990, change in cost 0.0268097
# final accuracy on test set: 0.9238095

# %%
##############################
### SAVE TRAINED VARIABLES ###
##############################

# Create Saver
saver = tf.train.Saver()
# Save variables to .ckpt file
saver.save(sess, "trained_variables.ckpt")

# Close tensorflow session
sess.close()
