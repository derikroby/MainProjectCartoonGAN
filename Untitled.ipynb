# %% [markdown]
# ### Generative adversarial networks (GANs)
# THey are deep neural net architectures comprising of a set of two networks which compete against the other, hence the name “adversarial”. GANs were introduced in a paper by Ian Goodfellow and other researchers at the University of Montreal, including Yoshua Bengio, in 2014.

# %% [markdown]
# Firstly, we import the necessary libraries and read in the MNIST dataset from tensorflow.examples.tutorials.mnist .

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.examples.tutorials.mnist import input_data

mnist=input_data.read_data_sets("MNIST_data")
# Out:
# WARNING:tensorflow:From <ipython-input-1-17de0219ae63>:6: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /home/derik/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /home/derik/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /home/derik/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /home/derik/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %% [markdown]
# Create two functions which respresent the two networks.
# Both the networks have two hidden layers and an output layer which are densely or fully connected layers.

# %%
def generator(z,reuse=None):
    with tf.variable_scope('gen',reuse=reuse):
        hidden1=tf.layers.dense(inputs=z,units=128,activation=tf.nn.leaky_relu)
        hidden2=tf.layers.dense(inputs=hidden1,units=128,activation=tf.nn.leaky_relu)
        output=tf.layers.dense(inputs=hidden2,units=784,activation=tf.nn.tanh)
        
        return output
    
def discriminator(X,reuse=None):
    with tf.variable_scope('dis',reuse=reuse):
        hidden1=tf.layers.dense(inputs=X,units=128,activation=tf.nn.leaky_relu)
        hidden2=tf.layers.dense(inputs=hidden1,units=128,activation=tf.nn.leaky_relu)
        logits=tf.layers.dense(hidden2,units=1)
        output=tf.sigmoid(logits)
        
        return output,logits

# %% [markdown]
# Now, we create the placholders for our inputs. real_images are the actual images from MNIST and z is a 100 random pixels from the actual images. In order for the discriminator to classify it first has to know what the real images look like, so we have two calls to the discriminator function, the first two learn the actual images and the second two identify the fake images. reuse is set to true because when the same variables are used in two function calls the tensorflow computation graph gets an ambiguous signals and tends to throw value errors. Hence, we set the reuse parameter to True to avoid such errors.

# %%
tf.reset_default_graph()

real_images=tf.placeholder(tf.float32,shape=[None,784])
z=tf.placeholder(tf.float32,shape=[None,100])

G=generator(z)
D_output_real,D_logits_real=discriminator(real_images)
D_output_fake,D_logits_fake=discriminator(G,reuse=True)

# %% [markdown]
# Next, we define the loss function for our network. The labels_in parameter gives an target label for the loss function based on which it performs the calculations.
# The second argument for D_real_loss is tf.ones_like as we aim to produce true labels for all real images,but we add a bit of noise so as to address the problem of overpowering.

# %%
def loss_func(logits_in,labels_in):
    return tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=logits_in,labels=labels_in))

D_real_loss=loss_func(D_logits_real,tf.ones_like(D_logits_real)*0.9) #Smoothing for generalization
D_fake_loss=loss_func(D_logits_fake,tf.zeros_like(D_logits_real))
D_loss=D_real_loss+D_fake_loss

G_loss= loss_func(D_logits_fake,tf.ones_like(D_logits_fake))

# %% [markdown]
# When we have two seperate networks interacting with each other we have to account for the variables in each networks scope. Hence, while defining the functions the tf.variable_scope was set. We will be using the Adam optimizer for this example. We set the batch_size and the number of epochs. Increasing the epochs lead to better results, so play around with it (preferably if you have access to GPU’s).

# %%
lr=0.001

#Do this when multiple networks interact with each other
tvars=tf.trainable_variables()  #returns all variables created(the two variable scopes) and makes trainable true
d_vars=[var for var in tvars if 'dis' in var.name]
g_vars=[var for var in tvars if 'gen' in var.name]

D_trainer=tf.train.AdamOptimizer(lr).minimize(D_loss,var_list=d_vars)
G_trainer=tf.train.AdamOptimizer(lr).minimize(G_loss,var_list=g_vars)

batch_size=100
epochs=1000
init=tf.global_variables_initializer()

# %% [markdown]
# Finally, we initiate the session and use the next_batch() method from the tensorflow helper functions to train the networks. We, grab a random sample from the generated samples of the Generator and append it to the samples list.

# %%
samples=[] #generator examples

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(epochs):
        num_batches=mnist.train.num_examples//batch_size
        for i in range(num_batches):
            batch=mnist.train.next_batch(batch_size)
            batch_images=batch[0].reshape((batch_size,784))
            batch_images=batch_images*2-1
            batch_z=np.random.uniform(-1,1,size=(batch_size,100))
            _=sess.run(D_trainer,feed_dict={real_images:batch_images,z:batch_z})
            _=sess.run(G_trainer,feed_dict={z:batch_z})
            
        print("on epoch{}".format(epoch))
        
        sample_z=np.random.uniform(-1,1,size=(1,100))
        gen_sample=sess.run(generator(z,reuse=True),feed_dict={z:sample_z})
        
        samples.append(gen_sample)

plt.imshow(samples[0].reshape(28,28))
plt.imshow(samples[99].reshape(28,28))
# Out:
# on epoch0
# on epoch1
# on epoch2
# on epoch3
# on epoch4
# on epoch5
# on epoch6
# on epoch7
# on epoch8
# on epoch9
# on epoch10
# on epoch11
# on epoch12
# on epoch13
# on epoch14
# on epoch15
# on epoch16
# on epoch17
# on epoch18
# on epoch19
# on epoch20
# on epoch21
# on epoch22
# on epoch23
# on epoch24
# on epoch25
# on epoch26
# on epoch27
# on epoch28
# on epoch29
# on epoch30
# on epoch31
# on epoch32
# on epoch33
# on epoch34
# on epoch35
# on epoch36
# on epoch37
# on epoch38
# on epoch39
# on epoch40
# on epoch41
# on epoch42
# on epoch43
# on epoch44
# on epoch45
# on epoch46
# on epoch47
# on epoch48
# on epoch49
# on epoch50
# on epoch51
# on epoch52
# on epoch53
# on epoch54
# on epoch55
# on epoch56
# on epoch57
# on epoch58
# on epoch59
# on epoch60
# on epoch61
# on epoch62
# on epoch63
# on epoch64
# on epoch65
# on epoch66
# on epoch67
# on epoch68
# on epoch69
# on epoch70
# on epoch71
# on epoch72
# on epoch73
# on epoch74
# on epoch75
# on epoch76
# on epoch77
# on epoch78
# on epoch79
# on epoch80
# on epoch81
# on epoch82
# on epoch83
# on epoch84
# on epoch85
# on epoch86
# on epoch87
# on epoch88
# on epoch89
# on epoch90
# on epoch91
# on epoch92
# on epoch93
# on epoch94
# on epoch95
# on epoch96
# on epoch97
# on epoch98
# on epoch99
# on epoch100
# on epoch101
# on epoch102
# on epoch103
# on epoch104
# on epoch105
# on epoch106
# on epoch107
# on epoch108
# on epoch109
# on epoch110
# on epoch111
# on epoch112
# on epoch113
# on epoch114
# on epoch115
# on epoch116
# on epoch117
# on epoch118
# on epoch119
# on epoch120
# on epoch121
# on epoch122
# on epoch123
# on epoch124
# on epoch125
# on epoch126
# on epoch127
# on epoch128
# on epoch129
# on epoch130
# on epoch131
# on epoch132
# on epoch133
# on epoch134
# on epoch135
# on epoch136
# on epoch137
# on epoch138
# on epoch139
# on epoch140
# on epoch141
# on epoch142
# on epoch143
# on epoch144
# on epoch145
# on epoch146
# on epoch147
# on epoch148
# on epoch149
# on epoch150
# on epoch151
# on epoch152
# on epoch153
# on epoch154
# on epoch155
# on epoch156
# on epoch157
# on epoch158
# on epoch159
# on epoch160
# on epoch161
# on epoch162
# on epoch163
# on epoch164
# on epoch165
# on epoch166
# on epoch167
# on epoch168
# on epoch169
# on epoch170
# on epoch171
# on epoch172
# on epoch173
# on epoch174
# on epoch175
# on epoch176
# on epoch177
# on epoch178
# on epoch179
# on epoch180
# on epoch181
# on epoch182
# on epoch183
# on epoch184
# on epoch185
# on epoch186
# on epoch187
# on epoch188
# on epoch189
# on epoch190
# on epoch191
# on epoch192
# on epoch193
# on epoch194
# on epoch195
# on epoch196
# on epoch197
# on epoch198
# on epoch199
# on epoch200
# on epoch201
# on epoch202
# on epoch203
# on epoch204
# on epoch205
# on epoch206
# on epoch207
# on epoch208
# on epoch209
# on epoch210
# on epoch211
# on epoch212
# on epoch213
# on epoch214
# on epoch215
# on epoch216
# on epoch217
# on epoch218
# on epoch219
# on epoch220
# on epoch221
# on epoch222
# on epoch223
# on epoch224
# on epoch225
# on epoch226
# on epoch227
# on epoch228
# on epoch229
# on epoch230
# on epoch231
# on epoch232
# on epoch233
# on epoch234
# on epoch235
# on epoch236
# on epoch237
# on epoch238
# on epoch239
# on epoch240
# on epoch241
# on epoch242
# on epoch243
# on epoch244
# on epoch245
# on epoch246
# on epoch247
# on epoch248
# on epoch249
# on epoch250
# on epoch251
# on epoch252
# on epoch253
# on epoch254
# on epoch255
# on epoch256
# on epoch257
# on epoch258
# on epoch259
# on epoch260
# on epoch261
# on epoch262
# on epoch263
# on epoch264
# on epoch265
# on epoch266
# on epoch267
# on epoch268
# on epoch269
# on epoch270
# on epoch271
# on epoch272
# on epoch273
# on epoch274
# on epoch275
# on epoch276
# on epoch277
# on epoch278
# on epoch279
# on epoch280
# on epoch281
# on epoch282
# on epoch283
# on epoch284
# on epoch285
# on epoch286
# on epoch287
# on epoch288
# on epoch289
# on epoch290
# on epoch291
# on epoch292
# on epoch293
# on epoch294
# on epoch295
# on epoch296
# on epoch297
# on epoch298
# on epoch299
# on epoch300
# on epoch301
# on epoch302
# on epoch303
# on epoch304
# on epoch305
# on epoch306
# on epoch307
# on epoch308
# on epoch309
# on epoch310
# on epoch311
# on epoch312
# on epoch313
# on epoch314
# on epoch315
# on epoch316
# on epoch317
# on epoch318
# on epoch319
# on epoch320
# on epoch321
# on epoch322
# on epoch323
# on epoch324
# on epoch325
# on epoch326
# on epoch327
# on epoch328
# on epoch329
# on epoch330
# on epoch331
# on epoch332
# on epoch333
# on epoch334
# on epoch335
# on epoch336
# on epoch337
# on epoch338
# on epoch339
# on epoch340
# on epoch341
# on epoch342
# on epoch343
# on epoch344
# on epoch345
# on epoch346
# on epoch347
# on epoch348
# on epoch349
# on epoch350
# on epoch351
# on epoch352
# on epoch353
# on epoch354
# on epoch355
# on epoch356
# on epoch357
# on epoch358
# on epoch359
# on epoch360
# on epoch361
# on epoch362
# on epoch363
# on epoch364
# on epoch365
# on epoch366
# on epoch367
# on epoch368
# on epoch369
# on epoch370
# on epoch371
# on epoch372
# on epoch373
# on epoch374
# on epoch375
# on epoch376
# on epoch377
# on epoch378
# on epoch379
# on epoch380
# on epoch381
# on epoch382
# on epoch383
# on epoch384
# on epoch385
# on epoch386
# on epoch387
# on epoch388
# on epoch389
# on epoch390
# on epoch391
# on epoch392
# on epoch393
# on epoch394
# on epoch395
# on epoch396
# on epoch397
# on epoch398
# on epoch399
# on epoch400
# on epoch401
# on epoch402
# on epoch403
# on epoch404
# on epoch405
# on epoch406
# on epoch407
# on epoch408
# on epoch409
# on epoch410
# on epoch411
# on epoch412
# on epoch413
# on epoch414
# on epoch415
# on epoch416
# on epoch417
# on epoch418
# on epoch419
# on epoch420
# on epoch421
# on epoch422
# on epoch423
# on epoch424
# on epoch425
# on epoch426
# on epoch427
# on epoch428
# on epoch429
# on epoch430
# on epoch431
# on epoch432
# on epoch433
# on epoch434
# on epoch435
# on epoch436
# on epoch437
# on epoch438
# on epoch439
# on epoch440
# on epoch441
# on epoch442
# on epoch443
# on epoch444
# on epoch445
# on epoch446
# on epoch447
# on epoch448
# on epoch449
# on epoch450
# on epoch451
# on epoch452
# on epoch453
# on epoch454
# on epoch455
# on epoch456
# on epoch457
# on epoch458
# on epoch459
# on epoch460
# on epoch461
# on epoch462
# on epoch463
# on epoch464
# on epoch465
# on epoch466
# on epoch467
# on epoch468
# on epoch469
# on epoch470
# on epoch471
# on epoch472
# on epoch473
# on epoch474
# on epoch475
# on epoch476
# on epoch477
# on epoch478
# on epoch479
# on epoch480
# on epoch481
# on epoch482
# on epoch483
# on epoch484
# on epoch485
# on epoch486
# on epoch487
# on epoch488
# on epoch489
# on epoch490
# on epoch491
# on epoch492
# on epoch493
# on epoch494
# on epoch495
# on epoch496
# on epoch497
# on epoch498
# on epoch499
# on epoch500
# on epoch501
# on epoch502
# on epoch503
# on epoch504
# on epoch505
# on epoch506
# on epoch507
# on epoch508
# on epoch509
# on epoch510
# on epoch511
# on epoch512
# on epoch513
# on epoch514
# on epoch515
# on epoch516
# on epoch517
# on epoch518
# on epoch519
# on epoch520
# on epoch521
# on epoch522
# on epoch523
# on epoch524
# on epoch525
# on epoch526
# on epoch527
# on epoch528
# on epoch529
# on epoch530
# on epoch531
# on epoch532
# on epoch533
# on epoch534
# on epoch535
# on epoch536
# on epoch537
# on epoch538
# on epoch539
# on epoch540
# on epoch541
# on epoch542
# on epoch543
# on epoch544
# on epoch545
# on epoch546
# on epoch547
# on epoch548
# on epoch549
# on epoch550
# on epoch551
# on epoch552
# on epoch553
# on epoch554
# on epoch555
# on epoch556
# on epoch557
# on epoch558
# on epoch559
# on epoch560
# on epoch561
# on epoch562
# on epoch563
# on epoch564
# on epoch565
# on epoch566
# on epoch567
# on epoch568
# on epoch569
# on epoch570
# on epoch571
# on epoch572
# on epoch573
# on epoch574
# on epoch575
# on epoch576
# on epoch577
# on epoch578
# on epoch579
# on epoch580
# on epoch581
# on epoch582
# on epoch583
# on epoch584
# on epoch585
# on epoch586
# on epoch587
# on epoch588
# on epoch589
# on epoch590
# on epoch591
# on epoch592
# on epoch593
# on epoch594
# on epoch595
# on epoch596
# on epoch597
# on epoch598
# on epoch599
# on epoch600
# on epoch601
# on epoch602
# on epoch603
# on epoch604
# on epoch605
# on epoch606
# on epoch607
# on epoch608
# on epoch609
# on epoch610
# on epoch611
# on epoch612
# on epoch613
# on epoch614
# on epoch615
# on epoch616
# on epoch617
# on epoch618
# on epoch619
# on epoch620
# on epoch621
# on epoch622
# on epoch623
# on epoch624
# on epoch625
# on epoch626
# on epoch627
# on epoch628
# on epoch629
# on epoch630
# on epoch631
# on epoch632
# on epoch633
# on epoch634
# on epoch635
# on epoch636
# on epoch637
# on epoch638
# on epoch639
# on epoch640
# on epoch641
# on epoch642
# on epoch643
# on epoch644
# on epoch645
# on epoch646
# on epoch647
# on epoch648
# on epoch649
# on epoch650
# on epoch651
# on epoch652
# on epoch653
# on epoch654
# on epoch655
# on epoch656
# on epoch657
# on epoch658
# on epoch659
# on epoch660
# on epoch661
# on epoch662
# on epoch663
# on epoch664
# on epoch665
# on epoch666
# on epoch667
# on epoch668
# on epoch669
# on epoch670
# on epoch671
# on epoch672
# on epoch673
# on epoch674
# on epoch675
# on epoch676
# on epoch677
# on epoch678
# on epoch679
# on epoch680
# on epoch681
# on epoch682
# on epoch683
# on epoch684
# on epoch685
# on epoch686
# on epoch687
# on epoch688
# on epoch689
# on epoch690
# on epoch691
# on epoch692
# on epoch693
# on epoch694
# on epoch695
# on epoch696
# on epoch697
# on epoch698
# on epoch699
# on epoch700
# on epoch701
# on epoch702
# on epoch703
# on epoch704
# on epoch705
# on epoch706
# on epoch707
# on epoch708
# on epoch709
# on epoch710
# on epoch711
# on epoch712
# on epoch713
# on epoch714
# on epoch715
# on epoch716
# on epoch717
# on epoch718
# on epoch719
# on epoch720
# on epoch721
# on epoch722
# on epoch723
# on epoch724
# on epoch725
# on epoch726
# on epoch727
# on epoch728
# on epoch729
# on epoch730
# on epoch731
# on epoch732
# on epoch733
# on epoch734
# on epoch735
# on epoch736
# on epoch737
# on epoch738
# on epoch739
# on epoch740
# on epoch741
# on epoch742
# on epoch743
# on epoch744
# on epoch745
# on epoch746
# on epoch747
# on epoch748
# on epoch749
# on epoch750
# on epoch751
# on epoch752
# on epoch753
# on epoch754
# on epoch755
# on epoch756
# on epoch757
# on epoch758
# on epoch759
# on epoch760
# on epoch761
# on epoch762
# on epoch763
# on epoch764
# on epoch765
# on epoch766
# on epoch767
# on epoch768
# on epoch769
# on epoch770
# on epoch771
# on epoch772
# on epoch773
# on epoch774
# on epoch775
# on epoch776
# on epoch777
# on epoch778
# on epoch779
# on epoch780
# on epoch781
# on epoch782
# on epoch783
# on epoch784
# on epoch785
# on epoch786
# on epoch787
# on epoch788
# on epoch789
# on epoch790
# on epoch791
# on epoch792
# on epoch793
# on epoch794
# on epoch795
# on epoch796
# on epoch797
# on epoch798
# on epoch799
# on epoch800
# on epoch801
# on epoch802
# on epoch803
# on epoch804
# on epoch805
# on epoch806
# on epoch807
# on epoch808
# on epoch809
# on epoch810
# on epoch811
# on epoch812
# on epoch813
# on epoch814
# on epoch815
# on epoch816
# on epoch817
# on epoch818
# on epoch819
# on epoch820
# on epoch821
# on epoch822
# on epoch823
# on epoch824
# on epoch825
# on epoch826
# on epoch827
# on epoch828
# on epoch829
# on epoch830
# on epoch831
# on epoch832
# on epoch833
# on epoch834
# on epoch835
# on epoch836
# on epoch837
# on epoch838
# on epoch839
# on epoch840
# on epoch841
# on epoch842
# on epoch843
# on epoch844
# on epoch845
# on epoch846
# on epoch847
# on epoch848
# on epoch849
# on epoch850
# on epoch851
# on epoch852
# on epoch853
# on epoch854
# on epoch855
# on epoch856
# on epoch857
# on epoch858
# on epoch859
# on epoch860
# on epoch861
# on epoch862
# on epoch863
# on epoch864
# on epoch865
# on epoch866
# on epoch867
# on epoch868
# on epoch869
# on epoch870
# on epoch871
# on epoch872
# on epoch873
# on epoch874
# on epoch875
# on epoch876
# on epoch877
# on epoch878
# on epoch879
# on epoch880
# on epoch881
# on epoch882
# on epoch883
# on epoch884
# on epoch885
# on epoch886
# on epoch887
# on epoch888
# on epoch889
# on epoch890
# on epoch891
# on epoch892
# on epoch893
# on epoch894
# on epoch895
# on epoch896
# on epoch897
# on epoch898
# on epoch899
# on epoch900
# on epoch901
# on epoch902
# on epoch903
# on epoch904
# on epoch905
# on epoch906
# on epoch907
# on epoch908
# on epoch909
# on epoch910
# on epoch911
# on epoch912
# on epoch913
# on epoch914
# on epoch915
# on epoch916
# on epoch917
# on epoch918
# on epoch919
# on epoch920
# on epoch921
# on epoch922
# on epoch923
# on epoch924
# on epoch925
# on epoch926
# on epoch927
# on epoch928
# on epoch929
# on epoch930
# on epoch931
# on epoch932
# on epoch933
# on epoch934
# on epoch935
# on epoch936
# on epoch937
# on epoch938
# on epoch939
# on epoch940
# on epoch941
# on epoch942
# on epoch943
# on epoch944
# on epoch945
# on epoch946
# on epoch947
# on epoch948
# on epoch949
# on epoch950
# on epoch951
# on epoch952
# on epoch953
# on epoch954
# on epoch955
# on epoch956
# on epoch957
# on epoch958
# on epoch959
# on epoch960
# on epoch961
# on epoch962
# on epoch963
# on epoch964
# on epoch965
# on epoch966
# on epoch967
# on epoch968
# on epoch969
# on epoch970
# on epoch971
# on epoch972
# on epoch973
# on epoch974
# on epoch975
# on epoch976
# on epoch977
# on epoch978
# on epoch979
# on epoch980
# on epoch981
# on epoch982
# on epoch983
# on epoch984
# on epoch985
# on epoch986
# on epoch987
# on epoch988
# on epoch989
# on epoch990
# on epoch991
# on epoch992
# on epoch993
# on epoch994
# on epoch995
# on epoch996
# on epoch997
# on epoch998
# on epoch999

# %%
plt.imshow(samples[99].reshape(28,28))
